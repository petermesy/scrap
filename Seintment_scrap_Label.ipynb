# %% [markdown]
# <a href="https://colab.research.google.com/github/petermesy/scrap/blob/main/Seintment_scrap_Label.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install google-api-python-client
# Out:
# Requirement already satisfied: google-api-python-client in /usr/local/lib/python3.11/dist-packages (2.168.0)
# Requirement already satisfied: httplib2<1.0.0,>=0.19.0 in /usr/local/lib/python3.11/dist-packages (from google-api-python-client) (0.22.0)
# Requirement already satisfied: google-auth!=2.24.0,!=2.25.0,<3.0.0,>=1.32.0 in /usr/local/lib/python3.11/dist-packages (from google-api-python-client) (2.38.0)
# Requirement already satisfied: google-auth-httplib2<1.0.0,>=0.2.0 in /usr/local/lib/python3.11/dist-packages (from google-api-python-client) (0.2.0)
# Requirement already satisfied: google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0,>=1.31.5 in /usr/local/lib/python3.11/dist-packages (from google-api-python-client) (2.24.2)
# Requirement already satisfied: uritemplate<5,>=3.0.1 in /usr/local/lib/python3.11/dist-packages (from google-api-python-client) (4.1.1)
# Requirement already satisfied: googleapis-common-protos<2.0.0,>=1.56.2 in /usr/local/lib/python3.11/dist-packages (from google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0,>=1.31.5->google-api-python-client) (1.70.0)
# Requirement already satisfied: protobuf!=3.20.0,!=3.20.1,!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<7.0.0,>=3.19.5 in /usr/local/lib/python3.11/dist-packages (from google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0,>=1.31.5->google-api-python-client) (5.29.4)
# Requirement already satisfied: proto-plus<2.0.0,>=1.22.3 in /usr/local/lib/python3.11/dist-packages (from google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0,>=1.31.5->google-api-python-client) (1.26.1)
# Requirement already satisfied: requests<3.0.0,>=2.18.0 in /usr/local/lib/python3.11/dist-packages (from google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0,>=1.31.5->google-api-python-client) (2.32.3)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /usr/local/lib/python3.11/dist-packages (from google-auth!=2.24.0,!=2.25.0,<3.0.0,>=1.32.0->google-api-python-client) (5.5.2)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.11/dist-packages (from google-auth!=2.24.0,!=2.25.0,<3.0.0,>=1.32.0->google-api-python-client) (0.4.2)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.11/dist-packages (from google-auth!=2.24.0,!=2.25.0,<3.0.0,>=1.32.0->google-api-python-client) (4.9.1)
# Requirement already satisfied: pyparsing!=3.0.0,!=3.0.1,!=3.0.2,!=3.0.3,<4,>=2.4.2 in /usr/local/lib/python3.11/dist-packages (from httplib2<1.0.0,>=0.19.0->google-api-python-client) (3.2.3)
# Requirement already satisfied: pyasn1<0.7.0,>=0.6.1 in /usr/local/lib/python3.11/dist-packages (from pyasn1-modules>=0.2.1->google-auth!=2.24.0,!=2.25.0,<3.0.0,>=1.32.0->google-api-python-client) (0.6.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests<3.0.0,>=2.18.0->google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0,>=1.31.5->google-api-python-client) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests<3.0.0,>=2.18.0->google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0,>=1.31.5->google-api-python-client) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests<3.0.0,>=2.18.0->google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0,>=1.31.5->google-api-python-client) (2.4.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests<3.0.0,>=2.18.0->google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0,>=1.31.5->google-api-python-client) (2025.1.31)

# %%
import os
import json
from googleapiclient.discovery import build
import re
from transformers import pipeline

# %%
def clean_comment(text):

    text = re.sub(r"http\S+|www\S+", "", text)

    emoji_pattern = re.compile(
        "["
        "\U0001F600-\U0001F64F"  # Emoticons
        "\U0001F300-\U0001F5FF"  # Symbols & Pictographs
        "\U0001F680-\U0001F6FF"  # Transport & Map Symbols
        "\U0001F1E0-\U0001F1FF"  # Flags
        "\U00002702-\U000027B0"  # Dingbats
        "\U000024C2-\U0001F251"  # Enclosed Characters
        "\U0000200D"             # Zero Width Joiner
        "\U0001F900-\U0001F9FF"  # Supplemental Symbols and Pictographs
        "\U0001FA70-\U0001FAFF"  # Symbols and Pictographs Extended-A
        "\U00002600-\U000026FF"  # Miscellaneous Symbols
        "\U00002300-\U000023FF"  # Miscellaneous Technical
        "]+",
        flags=re.UNICODE,
    )
    text = emoji_pattern.sub("", text)

    text = re.sub(r"[a-zA-Z]", "", text)

    text = re.sub(r"\s+", " ", text).strip()
    # remove unneccessary tags like <>
    text = re.sub(r"<[^>]+>", "", text)



    return text

# %%
def fetch_amharic_comments(video_id, api_key):

    youtube = build("youtube", "v3", developerKey=api_key)

    amharic_comments = []
    next_page_token = None

    while True:
        request = youtube.commentThreads().list(
            part="snippet",
            videoId=video_id,
            pageToken=next_page_token,
            maxResults=100
        )
        response = request.execute()

        for item in response.get("items", []):
            comment = item["snippet"]["topLevelComment"]["snippet"]
            text = comment["textDisplay"]
            if re.search(r'[\u1200-\u137F]', text):
                cleaned_text = clean_comment(text)
                if cleaned_text:  # Only add if the cleaned text is not empty
                    amharic_comments.append({
                        "comment_id": item["id"],
                        "text": cleaned_text,
                        # "author": comment.get("authorDisplayName", "Unknown"),
                        # "published_at": comment["publishedAt"]
                    })

        next_page_token = response.get("nextPageToken")
        if not next_page_token:
            break

    return amharic_comments

# %%
def save_comments_to_jsonl(comments, folder, filename):

    os.makedirs(folder, exist_ok=True)

    filepath = os.path.join(folder, filename)
    with open(filepath, "w", encoding="utf-8") as f:
        for comment in comments:
            f.write(json.dumps(comment, ensure_ascii=False) + "\n")
    print(f"Comments saved to {filepath}")

# %%
if __name__ == "__main__":
    api_key = "YOUR API KEY"

    video_ids = [
        "peIQN5jueQ0",
        "46cVVbBGbjY",
        "jIqOI662_dA",
        "_YddTPxw_68",
        "VT82OK6n3jw",
        "FsEEU4p5BZk",
        "0aP3FCNYbVc",
        "Lu8Or-WFZsk",
        "2aAU4m_uoTw",
        "rY_yW8QSSuQ",
        "hGMBe6Agq9c",
        "dXdAxoC4Pcc",
        "gV0fb0MGuH0",
        "a93nBqQJFOU",
        "hGMBe6Agq9c",
        "jIqOI662_dA",
        "hc_fCgoC4no",
        "_p2ihJ81Xno",
        "pdGZZ54rmBM",
        "IE2AeGsBszA",
        "JPJsvIdqSIc",
        "ppfP5ZAO-Hg",


    ]

    output_folder = "Amharic_comments"

    for video_id in video_ids:
        print(f"Fetching Amharic comments for video ID: {video_id}")
        amharic_comments = fetch_amharic_comments(video_id, api_key)

        filename = f"comments_{video_id}.jsonl"
        save_comments_to_jsonl(amharic_comments, output_folder, filename)
# Out:
# Fetching Amharic comments for video ID: peIQN5jueQ0
# Comments saved to Amharic_comments/comments_peIQN5jueQ0.jsonl
# Fetching Amharic comments for video ID: 46cVVbBGbjY
# Comments saved to Amharic_comments/comments_46cVVbBGbjY.jsonl
# Fetching Amharic comments for video ID: jIqOI662_dA
# Comments saved to Amharic_comments/comments_jIqOI662_dA.jsonl
# Fetching Amharic comments for video ID: _YddTPxw_68
# Comments saved to Amharic_comments/comments__YddTPxw_68.jsonl
# Fetching Amharic comments for video ID: VT82OK6n3jw
# Comments saved to Amharic_comments/comments_VT82OK6n3jw.jsonl
# Fetching Amharic comments for video ID: FsEEU4p5BZk
# Comments saved to Amharic_comments/comments_FsEEU4p5BZk.jsonl
# Fetching Amharic comments for video ID: 0aP3FCNYbVc
# Comments saved to Amharic_comments/comments_0aP3FCNYbVc.jsonl
# Fetching Amharic comments for video ID: Lu8Or-WFZsk
# Comments saved to Amharic_comments/comments_Lu8Or-WFZsk.jsonl
# Fetching Amharic comments for video ID: 2aAU4m_uoTw
# Comments saved to Amharic_comments/comments_2aAU4m_uoTw.jsonl
# Fetching Amharic comments for video ID: rY_yW8QSSuQ
# Comments saved to Amharic_comments/comments_rY_yW8QSSuQ.jsonl
# Fetching Amharic comments for video ID: hGMBe6Agq9c
# Comments saved to Amharic_comments/comments_hGMBe6Agq9c.jsonl
# Fetching Amharic comments for video ID: dXdAxoC4Pcc
# Comments saved to Amharic_comments/comments_dXdAxoC4Pcc.jsonl
# Fetching Amharic comments for video ID: gV0fb0MGuH0
# Comments saved to Amharic_comments/comments_gV0fb0MGuH0.jsonl
# Fetching Amharic comments for video ID: a93nBqQJFOU
# Comments saved to Amharic_comments/comments_a93nBqQJFOU.jsonl
# Fetching Amharic comments for video ID: hGMBe6Agq9c
# Comments saved to Amharic_comments/comments_hGMBe6Agq9c.jsonl
# Fetching Amharic comments for video ID: jIqOI662_dA
# Comments saved to Amharic_comments/comments_jIqOI662_dA.jsonl
# Fetching Amharic comments for video ID: hc_fCgoC4no
# Comments saved to Amharic_comments/comments_hc_fCgoC4no.jsonl
# Fetching Amharic comments for video ID: _p2ihJ81Xno
# Comments saved to Amharic_comments/comments__p2ihJ81Xno.jsonl
# Fetching Amharic comments for video ID: pdGZZ54rmBM
# Comments saved to Amharic_comments/comments_pdGZZ54rmBM.jsonl
# Fetching Amharic comments for video ID: IE2AeGsBszA
# Comments saved to Amharic_comments/comments_IE2AeGsBszA.jsonl
# Fetching Amharic comments for video ID: JPJsvIdqSIc
# Comments saved to Amharic_comments/comments_JPJsvIdqSIc.jsonl
# Fetching Amharic comments for video ID: ppfP5ZAO-Hg
# Comments saved to Amharic_comments/comments_ppfP5ZAO-Hg.jsonl

# %%
def read_comments_from_folder(folder_path):

    all_comments = []

    # Iterate through all files in the folder
    for filename in os.listdir(folder_path):
        if filename.endswith(".jsonl"):  # Process only JSONL files
            file_path = os.path.join(folder_path, filename)
            print(f"Reading comments from: {file_path}")

            # Read the JSONL file
            with open(file_path, "r", encoding="utf-8") as f:
                for line in f:
                    comment_data = json.loads(line.strip())
                    all_comments.append(comment_data["text"])  # Extract the comment text

    return all_comments

# %%
positive_keywords = [
    "ጥሩ", "አሪፍ", "በጣም ጥሩ", "አመሰግናለሁ","ሙዚቃው ያምራል","አስደሳች ታሪክ","ድንቅ ዳይሬክሽን","የማይረሳ","አስደናቂ ትወና",
    "አስቂኝ","አስደማሚ","ምርጥ","ድንቅ","አስደናቂ","አስደሳች","በርቱ","ፍቅር","በፍቅር","የፍቅር","ማፍቀር","መፈቀር"
     "ጥሩ", "ውብ", "ምርጥ", "ተሳክቷል", "ደስ የሚል", "አስደሳች", "እምነት የሚጣልበት", "ፈጣን", "ቀልጣፋ", "ተመችቷል",
    "ድጋፍ", "ያበረታታል", "ይደግፋል", "እውነት", "ፍትህ", "ሰላም", "ልማት", "ለውጥ", "ጀግና", "አርበኛ",
    "ዴሞክራሲ", "ይሻላል", "ተስፋ", "ድል", "ተስፋ ሰጪ", "አኩሪ", "የሚያነቃቃ", "አስተዋጽኦ", "እድገት", "ብልጽግና",
    "አንድነት", "መተባበር", "ሰላማዊ", "እርቅ", "መቻቻል", "እኩልነት", "ነጻነት", "ልማታዊ", "ተራማጅ", "ድምቀት",
    "ክብር", "አስደናቂ", "ድንቅ", "ጎበዝ", "አስተዋይ", "ትሁት", "ጨዋ", "አሳማኝ", "አነቃቂ", "አርአያ",
    "ተደማጭነት", "ቅንነት", "ትጋት", "አስደሳች", "አስደማሚ", "አስቂኝ", "አስደናጋጭ", "የማይረሳ", "ያምራል", "ይበልጣል",
    "ይፈውሳል", "ያድናል", "ያግዛል", "የተባረከ", "ያበራል", "ያበለጽጋል", "ያከብራል", "ያሞግሳል", "የተመሰገነ",
    "የተወደደ", "የተከበረ", "የተወደሰ", "የከበረ", "ድንቅ ስራ", "ፍጹም", "ድንቅ ችሎታ", "ብሩህ አእምሮ", "ጥሩ ምግባር",
    "መልካም ልብ", "ጽኑ እምነት", "አዎንታዊ", "ቆንጆ", "ሠናይ", "ያማረ", "የከበረ", "ትልቅ", "ታላቅ", "ድንቅ ሐሳብ",
    "ትክክል", "የተሳካ", "ጥሩ ውጤት", "በረከት", "ምስጋና", "ክብር ይሁን", "ይባረክ", "ያድግ", "ይለምልም", "ይበልጽግ",
    "ይዳብር", "ይስፋፋ", "ይስመር", "ይፈጸም", "ይከናወን", "ይፈጸምልን", "ይከናወንልን", "ይሳካልን", "ይስመርልን", "ይዳብርልን",
    "ይለምልምልን", "ይበልጽግልን", "ይስፋፋልን", "የተወደደ ይሁን", "የተከበረ ይሁን", "የተመሰገነ ይሁን", "ያንጸባርቃል", "ያበራልናል", "ያበለጽገናል",
    "ያከብረናል", "ያሞግሰናል", "ያግዘናል", "ያድነናል", "ይፈውሰናል", "ያድጋልናል", "የተባረከ ይሁንልን", "ያማረ ይሁንልን", "ሠናይ ይሁንልን",
    "ቆንጆ ይሁንልን", "አዎንታዊ ይሁንልን", "ብሩህ ይሁንልን", "ፍጹም ይሁንልን", "መልካም ይሁንልን", "ትክክል ይሁንልን", "የተሳካ ይሁንልን", "ታላቅ ይሁንልን",
    "ትልቅ ይሁንልን", "የከበረ ይሁንልን", "ያማረ ሐሳብ", "ድንቅ ችሎታ", "ጥሩ ምግባር", "መልካም ልብ", "ጽኑ እምነት", "ያድናልናል", "ያግዘናልናል",
    "ይፈውሰናልናል", "ያበራልናልናል", "ያበለጽገናልናል", "ያከብረናልናል", "ያሞግሰናልናል", "ይበልጣልናልናል", "ይሻላልናልናል", "ያበረታታልናልናል", "ያነቃቃልናልናል",
    "ያድጋልናልናል", "ይለምልማልናልናል", "ይበልጽጋልናልናል", "ይዳብራልናልናል", "ይስፋፋልናልናል", "ይስመራልናልናል", "ይፈጸማልናልናል", "ይከናወናልናልናል", "ይሳካልናልናል",
    "ይስመራልናልናል", "ይዳብራልናልናል", "ይለምልማልናልናል", "ይበልጽጋልናልናል", "ይስፋፋልናልናል", "ይፈጸማልናልናል", "ይከናወናልናልናል", "ይሳካልናልናል",
    "ይስመራልናልናል", "ይዳብራልናልናል", "ይለምልማልናልናል", "ይበልጽጋልናልናል", "ይስፋፋልናልናል", "ይፈጸማልናልናል", "ይከናወናልናልናል", "ይሳካልናልናል",
    "ይስመራልናልናል", "ይዳብራልናልናል", "ይለምልማልናልናል", "ይበልጽጋልናልናል", "ይስፋፋልናልናል", "ይፈጸማልናልናል", "ይከናወናልናልናል", "ይሳካልናልናል",
    "ይስመራልናልናል", "ይዳብራልናልናል", "ይለምልማልናልናል", "ይበልጽጋልናልናል", "ይስፋፋልናልናል", "ይፈጸማልናልናል", "ይከናወናልናልናል", "ይሳካልናልናል",
    "ይስመራልናልናል", "ይዳብራልናልናል", "ይለምልማልናል",""
    ]
negative_keywords = [
    "መጥፎ","እየዘረፈ","ዘረፈ","ገደለ","እየገደለ", "አልወደድኩም", "አስቸጋሪ", "አልቻልኩም","አሰልቺ","የሚያበሳጭ","ደካማ" "ታሪክ",
    "አስመሳይ ትወና","አስከፊ ዳይሬክሽን","የማይረባ","አሳዛኝ","ጊዜ ማባከን","ድክመት","አስፈሪ","ይረሸኑ","መስረቅ","ሰረቀ","በሰበሰ","መበሰበሰ","አበሰበሰ",
        "መጥፎ", "አስከፊ", "ዘገየ", "ችግር", "ተበላሽቷል", "አልተሳካም", "አሳዛኝ", "ያሳዝናል", "አይደለም", "አልወደድኩትም",
    "ተቃውሞ", "ይቃወማል", "ውሸት", "ግፍ", "ጦርነት", "ድህነት", "ሙስና", "አምባገነን", "ጨቋኝ", "ዘረኝነት",
    "ትርምስ", "ይከፋል", "ተስፋ መቁረጥ", "ውድቀት", "አደጋ", "ግጭት", "ሽብር", "አመጽ", "ዝርፊያ", "ግድያ",
    "እልቂት", "ዘር ማጥፋት", "ወንጀል", "ብጥብጥ", "አለመረጋጋት", "አፈና", "አድልዎ", "አድማ", "ትችት", "ውግዘት",
    "ውርደት", "ኋላቀርነት", "ትዕቢተኛ", "እብሪተኛ", "አላዋቂ", "ደካማ", "አሰልቺ", "አሳፋሪ", "ውሸታም", "አጭበርባሪ",
    "ትችት የሚበዛበት", "ጉድለት", "ቸልተኛ", "የሚያበሳጭ", "አስመሳይ", "አስፈሪ", "የማይረባ", "ጊዜ ማባከን", "ድክመት", "ይጎዳል",
    "ያጠፋል", "ይገድላል", "ይጎዳልናል", "ያጠፋልናል", "ይገድላልናል", "ይጎዳልናልናል", "ያጠፋልናልናል", "ይገድላልናልናል", "ጭካኔ", "ክፋት",
    "መጥፎ ዕድል", "መከራ", "ሐዘን", "ቁጣ", "ጥላቻ", "ንቀት", "ንቀት የተሞላበት", "ተንኮል", "ተንኮለኛ", "ሐሰት",
    "ውሸት የተሞላበት", "ማታለል", "ማጭበርበር", "አሳሳች", "አታላይ", "አታላይነት", "አሳሳችነት", "አታላይ ተግባር", "አሳሳች ተግባር",
    "አሳፋሪ ተግባር", "አሳዛኝ ሁኔታ", "አሳዛኝ ዜና", "አስጨናቂ", "አስጨናቂ ሁኔታ", "አስጨናቂ ዜና", "ያሳዝናልናል",
    "ተወው","ተወኝ","መተው","አስጸያፊ","አስከፊ","አስከፊነት","አስቸጋሪ","አስቂኝ","አስቂኝነት","ጥፋት","አስጸያፊ","ክስ መነሳት",
    "ክስ","እርግማን","ህመም","ህመም ያለው","ጉስቁልኝ","ጉስቁልነት","ጠላት","ጠላኝ","ችግር","መከራ","መከራና ችግር","መከራ አስከባሪ",
    "አስቸጋሪ","አስቸጋሪነት","አስቸጋሪ አመለካከት","አስቸጋሪነት","አስቸጋሪ ሁኔታ","ማስፈራራት","ማስቀመጥ","ቁጣ","ቁጣማ","ማስቆጣት",
    "አስቆጣሪነት","አስቆጣሪ","ጠላኝነት","ጠላትነት","ጠላኝነት ያለው","ጭንቀት","ጭንቀት ያለው","አስፈሪ","አስቀራርቅ","አስቀራርቅ ያለው",
    "ኩራት","ኩራትነት","አሳፋሪ","አሳፋሪነት","አስፈሪ","አስፈሪነት","እምቢነት", "እምነት የሌለው", "ውሸታም", "ውሸት", "ስህተት",
    "ራብ", "ድካም", "ፍርሃት", "ፍርሃታማ", "ደካማ", "ጠብ", "ቆሻሻ", "ጉድለት ያለው", "ሞኝ", "ሞኝነት", "መከልከል", "የተከለከለ",
    "ማስታወስ የማይችል", "ተወላለፈ", "ስብራት", "ቀጭን", "ማጭበርበር", "ፍርሃት", "ማስፈራራት", "የተፈራ", "ሚያስፈራ", "አስቀያሚ", "ማስቸገር"
    ]

# %%
def label_comment(comment):
    """
    Labels a comment as positive, negative, or neutral based on keywords.
    """
    # Check for negative keywords first
    # if any(word in comment for word in negative_keywords):
    #     print(f"Matched negative keyword in comment: {comment}")
    #     return "negative"

    # # Check for positive keywords
    # elif any(word in comment for word in positive_keywords):
    #     print(f"Matched positive keyword in comment: {comment}")
    #     return "positive"

    for word in negative_keywords:
        if f" {word} " in f" {comment} ":
            print(f"Matched negative keyword: {word} in comment: {comment}")
            return "negative"

    # Check for positive keywords
    for word in positive_keywords:
        if f" {word} " in f" {comment} ":
            print(f"Matched positive keyword: {word} in comment: {comment}")
            return "positive"
    # If no keywords match, label as neutral
    else:
        print(f"No keywords matched for comment: {comment}")
        return "neutral"

# %%
def save_labeled_data_to_jsonl(labeled_data, output_file):
    """
    Saves labeled data to a JSONL file.

    Args:
        labeled_data (list): A list of dictionaries containing labeled comments.
        output_file (str): The path to the output JSONL file.
    """
    with open(output_file, "w", encoding="utf-8") as f:
        for data in labeled_data:
            f.write(json.dumps(data, ensure_ascii=False) + "\n")
    print(f"Labeled data saved to {output_file}")

# %%
if __name__ == "__main__":
    # Path to the folder containing JSONL files
    folder_path = "/content/Amharic_comments"

    # Read comments from the folder
    comments = read_comments_from_folder(folder_path)

    # Label the comments
    labeled_data = [{"comment": comment, "sentiment": label_comment(comment)} for comment in comments]

    # Print the labeled data
    for data in labeled_data:
        print(data)
    # Save the labeled data to a JSONL file
    output_file = "labeled_comments.jsonl"  # Replace with your desired output file path
    save_labeled_data_to_jsonl(labeled_data, output_file)
# Out:
# Streaming output truncated to the last 5000 lines.
# {'comment': 'ደስ ብሎኛል', 'sentiment': 'neutral'}
# {'comment': 'ወቸው ጉድ እዱሉን ብትሰጡኝ ደስ ይለኛል በጣም ፍላጎት አለኝ ለመማር', 'sentiment': 'neutral'}
# {'comment': 'በጣም መማር አፈልጋለሁ ፡፡ለተሻለ የስራ ጥራት ለመስራት ስለፈለግኩ ነው፡፡አክባሪያችሁም ነኝ፡፡', 'sentiment': 'neutral'}
# {'comment': '@80,000 የቲክቶክ አለኝ በዚህ ላይ ስልጠና ብጨምርበት የተሻለ ስራ እሰራለሁ። የወቸው ነኝ', 'sentiment': 'neutral'}
# {'comment': 'ስሜታዊ አትሁን አቶ እሸቱ', 'sentiment': 'neutral'}
# {'comment': '&#39; እና ሮቤል ይልቃል በማንኛውም አጋጣሚ ክፍተት ቢፈጥር', 'sentiment': 'neutral'}
# {'comment': 'እናቶችን ልጆቻቸውን በቀላሉ በቤት ውስጥ የሚያስተምሩበት ለመስራት ለመጀመር ዝግጅት ላይ ነኝ እና እድሉ ለኔ ቢሰጠኝ ይጠቅመኛል አመሰግናለሁ', 'sentiment': 'positive'}
# {'comment': 'ወቸው', 'sentiment': 'neutral'}
# {'comment': 'ስራ ያስፈልገኛል ለስራ ደሞ እወቀት ያስፈልጋል ለዕዉቀት ደሞ መማር ከዛ እራስን ችሎ መኖር እየሰሩ የደከመዉ ሰዉ ኮመንት', 'sentiment': 'neutral'}
# {'comment': 'እሸ የእዉነት ሰዉ ሰላም ይብዛ ብሮ', 'sentiment': 'positive'}
# {'comment': 'እሼ በጌታ እኔን አግዙኝ በጣም ያስፈልገኛል የ ተማሪ ነኝ በአሁኑ ሰአት የግድ ያስፈልገኛል ገንዘብ መስራት ይኖርብኛል እሼ በጌታ ይሆንን እድል ለኔ ስጡኝ እየተማርኩም በነጻ አገለግላለሁ እጅግ በጣም ያስፈልገኛል በውስ አሉ ለመስራት እየመኮርኩ ነው እና አግዙኝ በነጻም እየሰራው አገለግላለሁ እያስተማርከኝ በጌታ', 'sentiment': 'neutral'}
# {'comment': 'እኔ በጣም ኤዲተር መሆን አለብኝ ምክንያቱም ክፍለሀገር ላይ የራሴን ሶሻል ሚዲያ ማርኬቲንግ ኤጀንሲ ጀምሬያለሁ ግን በጣም ከባድ የሆነብኝ ቪዲዮ ኤዲት ማድረግ ነው አግዙኝ ኤዲተር ልሁን ልስራ', 'sentiment': 'neutral'}
# {'comment': 'እኔን አስተምረኝ ሀረብ ሀገር ነኝ ሀገሬ እንድመለስ እርዱኝ', 'sentiment': 'neutral'}
# {'comment': 'አደራ እሺ', 'sentiment': 'neutral'}
# {'comment': 'የሚባል አለኝ። በኮሜዲያን እሸቱ የሚሰጠዉን የ ቢሰጠኝ . <><><> .', 'sentiment': 'neutral'}
# {'comment': 'እኔ ተማሪ ስለሆንኩ የ መክፈል ሃቅሙ የለግንም ፍላጎቴን ለማወቅ በ ግራፊክስ ዲዛይኒንግ ተምሬ ለምስራት እየሞከርኩ ነው ይሄን እድል ካገኝው ደስ ይለግናል.', 'sentiment': 'neutral'}
# {'comment': 'እራሴን ለመቻል ነው ከቤቴሰብ ሸክም ላይ ለመውረድ ነው ወቸው<><>', 'sentiment': 'neutral'}
# {'comment': 'እድሉን ስጡኝና ከድድ ማስጫ ልነሳ', 'sentiment': 'neutral'}
# {'comment': 'በማርያም ምክንያት አላበዛም ግን እድሉን ስጡኝ', 'sentiment': 'neutral'}
# {'comment': 'ይሄን እከካም ስታቀርቡት ዘጋችሁኝ ኦርቶዶክስን ይቅርታ ካልጠየቀ በእናንተም ላይ ዘመቻ ይጀመራል። ቁጥር 1 ፋናችሁ ነበርሁ', 'sentiment': 'neutral'}
# {'comment': 'ይሄን እከካም ስታቀርቡት ዘጋችሁኝ ኦርቶዶክስን ይቅርታ ካልጠየቀ በእናንተም ላይ ዘመቻ ይጀመራል። ቁጥር 1 ፋናችሁ ነበርሁ', 'sentiment': 'neutral'}
# {'comment': 'ልከርበት ወቸው ጉዶች', 'sentiment': 'neutral'}
# {'comment': 'ደብዳቤ', 'sentiment': 'neutral'}
# {'comment': 'አለመፃፍ አልቻልኩም<>ወቸው ..... <>ያበደ ነውውውውው ይላልልልልልል<>እኔ እቤት ተከልብቼ ነው የጀመርኩት<><> ለተከለበትኩበት', 'sentiment': 'neutral'}
# {'comment': 'ወቸው ከተከረበተ ቆየ', 'sentiment': 'neutral'}
# {'comment': 'አንደኛ ወቼው ጉዶች ትችላላችሁ ማሂዬ እወድሻለሁ', 'sentiment': 'neutral'}
# {'comment': 'ወቸው በርቱ !!!', 'sentiment': 'positive'}
# {'comment': 'ወቸው ጉድ ጉድ እኮ ነው።', 'sentiment': 'neutral'}
# {'comment': 'ታመልጥ መስሎሀል በሰጠሀው አስተያየት', 'sentiment': 'neutral'}
# {'comment': 'ቬሮኒካን አይቼ ነው ለመጀመሪያ ጊዜ ወቸው &#39;ን መከታተል የጀመርኩት', 'sentiment': 'neutral'}
# {'comment': 'ወቸው ጉድ ! ዛሬ ደግሞ እሸቱ መጣ', 'sentiment': 'neutral'}
# {'comment': 'መዳንም በሌላ በማንም የለም፤ እንድንበት ዘንድ የሚገባን ለሰዎች የተሰጠ ስም (ከኢየሱስ በስተቀር) ከሰማይ በታች ሌላ የለምና።', 'sentiment': 'neutral'}
# {'comment': 'አልተቻላችሁም', 'sentiment': 'neutral'}
# {'comment': 'እሱ በመጣበት መልኩ እኔም እመጣለው', 'sentiment': 'neutral'}
# {'comment': 'አይ እሸቱ ሲራቀቅ ወቸው ጉድ ላይ ገባ እኛ እንደሆንን ለቲክቶክ መቁረጣችን አይቀርም', 'sentiment': 'neutral'}
# {'comment': 'እሼ ወቸው ጉድ', 'sentiment': 'neutral'}
# {'comment': 'ትችላላችሁ', 'sentiment': 'neutral'}
# {'comment': 'የምላችሁ ልጅ ነኝ ከእሱ ብቀድምልኝ የምለው ሰው አግኝቻለሁ ቶክቻዉን ብታመጡልን እና እንደ እሼ እሱም ሰሞኑን ላይ ስለምያወራዉ ነገር ብትጠይቁልን??? ከቻላችሁ', 'sentiment': 'neutral'}
# {'comment': 'ወቸው', 'sentiment': 'neutral'}
# {'comment': 'አረ እኔንም ጋብዙኝ', 'sentiment': 'neutral'}
# {'comment': 'ከረብ ከረብ አርጉ', 'sentiment': 'neutral'}
# {'comment': 'አሼኮበመላስ ጤፍ ሚቆላ ሰው ነውሚመቻቹ በ', 'sentiment': 'neutral'}
# {'comment': 'በሰው ሚፈጠር ቺግር እንጂ በቺግር ሚፈጠር ሰው የለምአንድ ቀን ያሰብነው ቦታ እንደርሳለን', 'sentiment': 'neutral'}
# {'comment': 'ተከረበታችሁ ኮ ቆየ እኮ ከተከረበታችሁ አምነናል <>እንደውም የ24ሰአት ጀምሩልን ዜና ምናምን <>ትችላላችሁ <>ግቡለት', 'sentiment': 'neutral'}
# {'comment': 'እሸቱ ማለት በሱ አማካኝነት ስንት ቤተክርስቲያን ተሰርቷል አንርሳ እናስታውስ እንጂ', 'sentiment': 'neutral'}
# {'comment': 'ይሄንን ለ 1 ወር ከ 2 ሳምንት በጉጉት ስጠብቀው ነበር።ይቻላል ነው እምላቹ በቃ ዛሬ ምርጡን ቅዳሜ ምሽት እምር ብሎልኝ ነው ማሳልፈው ይመቻቹ', 'sentiment': 'neutral'}
# {'comment': 'ይቻላል እንዴ', 'sentiment': 'neutral'}
# {'comment': 'ማጠብቁት', 'sentiment': 'neutral'}
# {'comment': 'እናንተ ጋር ለመቅረብ ታትሬ እየተኛው ነው', 'sentiment': 'neutral'}
# {'comment': 'እሸቱ ማለት በእሱ አማካኝነት የስንቱ ደሀ እንባ ታብሷል አንዳንድ ሰዎች ግን እረፉ', 'sentiment': 'neutral'}
# {'comment': 'ለኔ በጣም ምርጡ ፖድካስት በረከት ራሱ ወቸው ጉድ ላይ ቀርቦ የነበረው ነው', 'sentiment': 'positive'}
# {'comment': 'ትችላላችሁ የአሜሪካውስ እነ አቤል ምስራቅ የት ገቡ', 'sentiment': 'neutral'}
# {'comment': 'ወቸው በርቱ !!!', 'sentiment': 'positive'}
# {'comment': 'ወቸው ጉድ', 'sentiment': 'neutral'}
# {'comment': 'እውነት ለመናገር ከወቅታዊ ጉዳዮች አንፃር አሁን ላይ እሸቱ ትንሽ ከኦርቶዶክሳውያን ጋር ውዝግብ ውስጥ ያለ ግለሰብ ነው ኦርቶዶክሳውያንን መከላከል ሲገባው ጭራሽ አሳልፎ ሰጪ ሆኖ አግኝቼው ደብሮኛል አላየውም', 'sentiment': 'positive'}
# {'comment': 'ወቸ ወቸ', 'sentiment': 'neutral'}
# {'comment': 'እናሲዝ ኢሄ የ ወቸው , ደግሞ ይሆናል<><>', 'sentiment': 'neutral'}
# {'comment': 'ወቸው ጉድ ታሪክ ትችላላቹ ይሜ', 'sentiment': 'neutral'}
# {'comment': 'ወቸው መገለባበጥ', 'sentiment': 'neutral'}
# {'comment': 'ማጠብቁት', 'sentiment': 'neutral'}
# {'comment': 'ወቸው ጉድ ይከረበታል', 'sentiment': 'neutral'}
# {'comment': 'ቢያንስ ከ1 አመት ተኩል በሃላ እኔ ነኝ እዚ ላይ የሚታገኙኝ', 'sentiment': 'neutral'}
# {'comment': 'አረ ባካቹ በጉጉት ሞትን ሆሆሆሆ', 'sentiment': 'neutral'}
# {'comment': 'እንዴ ማን ነበር ጎረቤታቸው ነኝ እሸቱ ነው የሚመጣው ያለው ወቸውውውውውውውጉድድድድድድድ ሌላ ታሪክ ተከረባበተ', 'sentiment': 'neutral'}
# {'comment': 'ወይኔ ወቸዉ ጉድ ታሪክ ሰሪ ፖድካስታችን', 'sentiment': 'neutral'}
# {'comment': 'አቤል ከ አሜሪካ ቢመጣ ባይ ነኝ እደ ሀሳብ', 'sentiment': 'neutral'}
# {'comment': 'ሳድግ ወቸው ጉድ ላይ መቅረብ ነው ምፈልገው', 'sentiment': 'neutral'}
# {'comment': 'አጨብጭበናል።', 'sentiment': 'neutral'}
# {'comment': 'ወቸው ተከረባበተ', 'sentiment': 'neutral'}
# {'comment': 'ውቸው ይለያሉ የምንለው በምክንያት ነው', 'sentiment': 'neutral'}
# {'comment': 'ትችላላችሁ', 'sentiment': 'neutral'}
# {'comment': 'ግባለትትትት....', 'sentiment': 'neutral'}
# {'comment': 'ወቸው ይገለበጣል ሳይሆን ዛሬ ተገለባበጠ ትችላላቹ', 'sentiment': 'neutral'}
# {'comment': 'እንደ ገመትኩት እሼ', 'sentiment': 'neutral'}
# {'comment': 'በቃ ተከርብቷልልል', 'sentiment': 'neutral'}
# {'comment': 'ወቸው ጉድ አቅም እንዳላቸው አሳዩን ቀጣይ ናቲ ማን ከቀረባልን በቃ ፊጥጨው ከሰይፉ ጋር ነው', 'sentiment': 'neutral'}
# {'comment': 'ይሄን ቦርኮ ልታቀርቡት ባልሆነ', 'sentiment': 'neutral'}
# {'comment': 'ወቸው ገና ይከረባበታል ነኝ ወቸው &#39; ግባለትትትትት', 'sentiment': 'neutral'}
# {'comment': 'ወቸው', 'sentiment': 'neutral'}
# {'comment': 'በቃ ትችላላችሁ ማሪያምን', 'sentiment': 'neutral'}
# {'comment': 'ወቸው ጉድድድድድ', 'sentiment': 'neutral'}
# {'comment': 'ወቸው ይችላል', 'sentiment': 'neutral'}
# {'comment': 'ይለያል እሼ', 'sentiment': 'neutral'}
# {'comment': 'ወቸው', 'sentiment': 'neutral'}
# {'comment': 'ዶክተር አብይ አህመድ አሊ ከፈጣሪ ለኢትዮጵያችን የተሰጠን ጸጋችን አሻጋሪ ሙሴያችን', 'sentiment': 'neutral'}
# {'comment': 'መሶብ', 'sentiment': 'neutral'}
# {'comment': 'ጥሩ ስራ ነው ኑርልን አብቹ !', 'sentiment': 'positive'}
# {'comment': 'አቦ ጀግና ነክ ትችላለክ በዛም በዚህ ተወጥረህ ኢሄናክል ካሳካህ ነፃብትሆን ኢትዮፕያ ምን እንደምታረጋት ፈጣሪ ይወቅ', 'sentiment': 'positive'}
# {'comment': 'ሞሶብ በእኔ አረዳድ ህብረነት ነው ፡ ግን አሁን ኢትዮጵያ ውስጥ ከማን ጋር ነው !እኔ የምወዳቸው !? እ', 'sentiment': 'neutral'}
# {'comment': 'ዝሙተኞች የዶክተሮን ሥራ እንደት እንደምያራክሱ እና እንድምያጥላሉ !! እኛ ኮንሶዎች ገና ወደ ስልጣን አንደ ወጡ ታይቶናል።', 'sentiment': 'neutral'}
# {'comment': 'አድራሻዉን ተናገሩ የት ነዉ ቦታዉ?', 'sentiment': 'neutral'}
# {'comment': 'አቢችዬ፦ የኛ ውድ መሪ።አንተን አውሎ ያግባልን እንጂ ገና ብዙ ብዙ ኢትዮጵያና ሕዝቦችዋ እናያለን።', 'sentiment': 'neutral'}
# {'comment': 'እግዚአብሔር ይባረክ!', 'sentiment': 'neutral'}
# {'comment': 'በመስራት የሚኖሩ ሁሌ እያተረፉ ፣ በወሬ የሚኖሩ እየከሰሩ ይኖራሉ ያልከዉ ፣ ሁልጊዜ እንደዚህ አይነት ምርቃት ሳይ፣ ትዝ ይለኛል። ዘመነ ካሴ ነው ያለው', 'sentiment': 'neutral'}
# {'comment': 'የክቡር ንጉሳችንን ስራዎቻቸውን ካስተዋልን የዘመናት ባለውለታችን ናቸው ለማለት እወዳለሁ እንደዚህ እየተተቹ የሚሰሩት ግሩምና ዘመን ተሻጋሪ ስራ ይበል የሚያስብል ነው።ስለትራውሬ አየር ተሰጥቶት ይወራል እንጂ ክቡር መሪያችን ለኛ ብቻ ሳይሆን ለአፍሪካ አይከን ናቸው', 'sentiment': 'neutral'}
# {'comment': 'ምን ማለት ይቻላል የሚገርም የኢትዮጵያ ጠ/ሚ ዶር አብይ አህመድ የኛ በመሆኖሆት ኮርቻለሁ', 'sentiment': 'neutral'}
# {'comment': 'ከኣንድ ጎሳ ስብስብ ነን ተብሎ የብዙሃንን ሃገር በሙሉ ለብቻችን ዕንመራለን በኛ የበላይነትና ልዩ ጥቅማችንን በማስጠበቅ ብለው ሃገር ለመምራት ማሰባቸው ብቻ፤ ወደ ቅራኔ ሁከት ትርምስ ኢፍትሐዊ ፣ ኣድሏዊ ኣተገባበር ስለሚያደላ ኣልፎም መሬት ተከልሎ ለጥቂት ጦር ጎሳሚ ተቀጣሪ ባንዳዎችን ለማስደሰት በወጡበት ጎሳ ጠርቶ ክልል ብሎ ኣፓርየይድን ማንገስማ ካራ ኣደለም ቦንብ ኣፋቸው ውስጥ ያስጎርሳቸዋል። የደረስኩበት ምርመራ ኣፍሪካውያን ላይ የተቃጣው የጥላቻ ጥቃት ስር ሰዶ ዕጅ ኣዙር ቅኝ ገዢዎች መላ የጥቁር ህዝብን ዕንቅስቃሴና መንግስታዊ መዋቅሮችን ዕንደተቆጣጠሩና፣ ይፖለቲካ ኣሰራር በመላ ዕንዳይሰራ፣ የኣፍሪካውያን መሰረታዊ ጥያቄዎች በቅድሚያ በደርጃ ዕንዳይመለሱ ግንባር ተሰልፈው ዕያከሸፉ ያሉ ስልጣኑን ተቆጣጥረው፣ በኣረብና በኣውሮፓውያን የተጀመረውን የማዕድንና ሃብት ምዝበራ ተክተው ዕየሰሩ ነው ያም ወደ ኣውሮፓ ኣሜሪካና ኣረብ ሃገራት ማጋዝ ኣፍሪካውያንን በሰበብ ኣስባብ ከግጭት ዕንዳይላቀቁ ተደርጎ ማደሕየት ነው። ኣፍሪካ ውስጥም ከኣፍሪካ ውጪም ኣረቡና ኣውሮፓውያኑ ተዝናንተው ተንዘባነው ተከብረው በልዩ መስተንግዶ ይሸኛሉ። ወገኖቼ ግን በብጣሽ ወረቀት ኣስተናጋጅና ጠጋኝ ሆነው ተሸማቀው ተቸግረው ዕንዲኖሩ መፈቀዱ ስለኣስቆጣኝ ኣምፃለሁ፣ ዕፋለማለሁ ፣ በምክክር በውይይት ተሞክሮ የመጣ ውጤት ኣልታየም ስለዚህ ዕዋጋለሑ። ዕናንተ ከመንደራችሁና ከጎሳችሁ ባህል ያልተላቀቃችሁ የውጪ ሃገራትን ጎብኝታችሁ የማታውቁ ስለኣለምና ሕይወትም ስለማትረዱ ኣደጋ ናችሑ። ሥለኣፍሪካዊነት ጥቁርነት፣ ስለቅኝገዢዎች ተንኮል፣ ስለባንዳዎች ሃይል ኣሰላለፍና የሚያደርሱብንን ስውርና ገሃዳዊ ጥቃቶችን ለማስረዳት ከብዷል። የጥቃቶቹ ብዛት፣ ለመከላከል የተደረጉ ዕንቅስቃሴዎች፣ ይጊዜና ቦታ ሁኔታና ኣቅም ማፈርጠምን በማገናዘብ የተወሰዱ ዕርምጃዎችን ካሳለፍናቸው ስቃይና ግዜያት ጋር ስናሰላስል፣ ኣሁንም ኣፍሪካዊው የማህበራዊ ኣሰራር፣ የፖለቲካ ኣሰራሩን ለማስተካከል ለማሻሻልና ለመሻሻል የሚወሰዱ ዕርምጃዎች ኣቅድና ዕቅድ በማጣታቸው፣ ኣንጋፋ ምሁሮቻችንና ሰልጠን ያሉ ወገኖቻችንን ለኣመራር ማብቃት ባለመቻሉ፣ ኣፍሪካዊው ተመቷል ወድቋል ለመነሳት ኣልቻለም ወደሚለው ድምዳሜ ኣድርሶናል። ይህ መሆኑ ደግሞ ዳግም ባርነትን ውርደትን የባሰ ድህነትን መጋበዝ ነው። <><>ከኢትዮጵያዊው ንፁህ ጥቁር ኣፍሪካዊው ፍርድ ኣወቅ ዘለቀ የግንዛቤ ፅሁፍ የተቀነጨበ ምክራዊ ማስተካከያና የጉዞ መርህ መቀየሻ ማሳደሚያና ቀና ማድረጊያ ቃላቶች ናቸው።', 'sentiment': 'negative'}
# {'comment': 'ለጠቅላይ ሚኒስትሩ የምስጋና መልእክት <>ጠቅላይ ሚኒስትሩ ሌብነትን ለመዋጋትና የጊዜ ብክነትን ለመቀነስ ሁሉን አቀፍ አገልግሎት የሚሰጥ ሥርዓት ስላስጀመሩልን ያለኝን ጥልቅ ምስጋና አቀርባለሁ። የራሳቸውን ሰምና ህይወት መስዋዕት ከፍለውም ቢሆን በማያወላውል ቁርጠኝነት ሀገርን ማገልገሉን ቀጥለዋል። <>ታሪካዊ የፖለቲካ ለውጥ ን እየመሩ ባለበት በዚህ ወቅት ብዙ ያልጠሩ ጉዳዮች በሌሉበት በዚህ ወቅት ፍቅር እና መደጋገፍ የማይታሰብ ቢሆንም፣ እሳቸው በሚረዱበት ሁኔታ ታላቅና እና የበለጸገች ሀገር ለመመስረት የሚያደርጉት ሁሉ እያደነቅሁኝ በድፍረት እንዲቀጥሉበት አበረታታለሁ። <> <> ራዕይዎ እና ፅናትዎ የቀጣዩ ትውልድ መነሳሳትን ይፈጥራል ።', 'sentiment': 'positive'}
# {'comment': '.እንወድሀለን', 'sentiment': 'neutral'}
# {'comment': 'እውነት ነው፣ የንግድ ፈቃድ ማስተካከያ ተገልግየ አይቸዋለሁ። በጣም ጥሩ ነው።እባካችሁ የሚባል አስቸጋሪ ቢሮ አለና ቢታይ!!!!!', 'sentiment': 'negative'}
# {'comment': 'የኢትዮጵያን ሕዝብ የመከራ ጽዋ እየጋትክ በራስህ አፍ በኢትዮጵያ ሕዝብ ስም ራስህን ከማመስገን ማረፍ አልቻልክም.... የምትጠራው ኢየሱስ ይፍረድ!', 'sentiment': 'neutral'}
# {'comment': 'ጤና እና ረጅም እድሜ ለአብቹና በቅንነት አብረውት ለምሰሩ ሀገር ወዳዶች ።', 'sentiment': 'neutral'}
# {'comment': 'አብይ እነመሰግነለን ለደረከልን ሁሉ ተተር መር እኖድሀለን', 'sentiment': 'neutral'}
# {'comment': 'ውድ ጠ/ሚ/ር ይህ ድንቅ ስራዎ አሁን በጠሯቸው ከተሞች እንደ አዳማ በአስቸኳይ ይሰራልን!!', 'sentiment': 'positive'}
# {'comment': 'እግዚአብሔር ይመስገን !!', 'sentiment': 'neutral'}
# {'comment': 'ለሀገሩ የሚጠቅም የሚየሰጠራ በየቀኑ ታምር የሚያሰራ አብቹ እግዚአብሔር ይባርክ። ገና ታሪክ ትሰራለህ አንተ።', 'sentiment': 'neutral'}
# {'comment': 'በጣም ጉበዝ መሪ', 'sentiment': 'neutral'}
# {'comment': 'አንድ ፎቅ ከ10 አመት በላይ ነበር የሚፈጀው አሁን ግን ድንቅ ነው', 'sentiment': 'positive'}
# {'comment': 'አረ አደማ ለይ ቶሎ በሉ ሕዝቡ በሙስና በጠም በጠም ተመራዋል', 'sentiment': 'neutral'}
# {'comment': 'ሌብነት ቢቆም ጦርነትም ይቆም ነበር ኢትዮጵያ ውስጥ ያለው ጦርነት ለሌብነት ሽፋን ለመስጠት ነው', 'sentiment': 'negative'}
# {'comment': 'በጣም ቁልፍ የኢትዮጵያ ን ችግር የሚፈታ ተቋም ነው በሐገራችን አንድ የሥራ መስክ የሚመስለውን ሙስና ለመዋጋት አንድ እርምጃ ነው!!!!!!! አተገባብር ላይ የምናየው ይሆናል????', 'sentiment': 'negative'}
# {'comment': 'ማሸአላህ አገሬ ሰላምሽ ይብዛልን አንደሰደት ከባድነው አገርውስጥ ያላቹህ አገራቹህን ውደዳት ማን እንደሀገር ምርጥ መሪ', 'sentiment': 'positive'}
# {'comment': 'አቢቹ ይሂቺ የባህር በር ብቻ ነች ችግርህ እንጂ: ሌላ በአገር ውስጥ እየሰራሀው ያለውን የለውጥ ስራ በጣም እጅግ የሚደነቅ ነው። ያ የወደብ ነገር ግን ሰከን ብለህ ግዜ ወስደህ አስብባት።<>እኔ ኤርትራዊ ነኝ: ያ በአስመራ የቡና ቁርስ ራስህ ተነስተህ ሌሎችን ስታስይዝ ያየሁት ምስል መክዳት አልችልም: አሁንም ረጋ ብለህ ለመጪው ትውልድ አስበህ ከኤርትራ ያለህን ነገር እንደምታስተካክል ተስፋ አረጋለሁኝ። ኤርትራ ማለት የድሮ አክሱም(ሰሜን ኢትዮጵያ የምያጠቃልል እንደሆነ መቸም አይነገርህም)። . . እኛ ከትግራይ ወንድሞቻችን አብረን ተግባብተን ከሰራን ደግሞ እሰዮ። የጋራ የ ኢኮኖሚ ዞን እናደርጋለን ለጋራ ጥቅም። እንደ እነ ጻድቃን አይነቶቹ ግን ባታጣምጣቸው እመክራለሁኝ። ‘ . . . ፈጣሪ ይርዳህ ። እኔ: የልማት ዜና መስማት ብቻ ነው የምናፍቀኝ: እንደ ሁሉ መስኪን ህዝብ።', 'sentiment': 'positive'}
# {'comment': 'ካዛንቺስ ሰፈር የገማ የሸተተ ጥርሱን የማይፍቅ ህዝብ የነበረበት ነዉ ያለው አብይ አህመድ እሱ አሜሪካ ነበረፈየተወለዉ የጥርስ ሳሙና በሻሻ ነበረ በሻሻ አልጋ ነበረ ቤቱ ቪላ የናጠጠ ነበረ ወይ በኮሪደሩ በተመረቀ ቁጥር ህዝብ የምሰድበዉን ዶክተር አቶ አብይ አህመድ መስደብ ይተዉ ነገ ሲያሳፍር ትዉለድ ይተዉ ሸለፈታም ሸታታ የገማ የአሽሽ መንደር የከረከሰ እያሉ አይሳደቡ እባኮት አፎትን ይጠመቁ', 'sentiment': 'neutral'}
# {'comment': 'እርፍት አልባው ታታሪው እንቅልፍ አልባው አብቹ አባመላ', 'sentiment': 'neutral'}
# {'comment': 'አንተ እንቁ የአላህ የፈጣሪ ስጦታችን አብቹ አላህ ይጠብቅህ ውሾቹ ይጮሀሉ ግመሎች ይጎዛሉ ነው ነገሩ በርታልን ወደፊት ብቻ', 'sentiment': 'neutral'}
# {'comment': 'የኔ ክቡር ++++አምላክ አብዝቶ ይባርክህ', 'sentiment': 'neutral'}
# {'comment': 'አላህ ያንሳህ አንተ እርኩስ ደደብ አንተ ደቆሮ ደጋፊዎችህ በሆዳቸው የሚአስቡ ደነዞች አላህ ቶለ ይገላግለን የሄን ሴረኞ', 'sentiment': 'neutral'}
# {'comment': 'ለመሪያችን እድሜና ጤና እለምናለሁ', 'sentiment': 'neutral'}
# {'comment': 'የጠቅላያችን ሀሣቡም እጆቹም ተባርከዋል ይጨመርለት', 'sentiment': 'neutral'}
# {'comment': 'አብቹ ጀግናችን ሺህ አመት ንገስልን', 'sentiment': 'neutral'}
# {'comment': 'ጀምሮ መጨረስን በአንተ ዘመን አየን ትውልድ ካንተ ብዙ ይማራል', 'sentiment': 'neutral'}
# {'comment': 'ጀግናው አብይ', 'sentiment': 'neutral'}
# {'comment': 'ኧረ ጉድ ነው!!! እንዲህም የሚሰራ አለ? ማንም መሪ እንዲህ ለአገሩ ተግቶ ሲሰራ አላየሁም!!! , !!!', 'sentiment': 'neutral'}
# {'comment': 'አቢቹ ሺ አመት ንገስ ይገርማል የእግዚአብሔር ስራ ድንቅ መሪ ሰጠን ክብር ለጌታ ይሁን', 'sentiment': 'positive'}
# {'comment': 'በቃ አብቹ ኦሮሚያ በፍጥነት ለሽመልስ አብዲሳ ካድሬዎች የአምቦ ዱርዬዎች ከተቻለ ሰውነታቸው ውስጥ በኦፕሬችን ኤ አይ አስገጥምላቸው ያው ለዘረኝነቱ ደግሞ ሌላ ሰፌድ ወይም ሙዳይ ብለህ ተመጣባቸዋለህ ኢንሻአላህ እኔ እምለው እስካሁን የዘረፋችሁትን አትጠየቁም እያልካቸው ነው ያ10 አመት ወደ ኅላ ሄዶ ሀብት ሚያጣራው ኮሚሽን ሌቦች በሉት ወይስ ወይስ ፈልሳፊው ኒቆጢሞስ ነው ምንም መልሶ ዋጠው መሶብ መጀመሪያ ያ የጫረታ አፕ ውስጥ ሁሉም የመንግስ መ/ቤቶች ይግቡበት', 'sentiment': 'neutral'}
# {'comment': 'በርታ! ለውጥ እና እድገት ብዙ ትግዳሮት እለው!', 'sentiment': 'positive'}
# {'comment': 'ሰበር : ይድረስ ለጠቅላይ ምንስትር ኩቡር ዶክተር አቢይ አህነድ .... በየ ጊዜው መህበራዊ ሚዲያን ላልተገባ ተግባር በሚጠቀሙ ድብቅ አላማና ድብቅ ተልእኮ ያላቸው ፂንፈኞች አገራችንን ከጎሮቤት አገሮች በማጋጨት ወደ ጦርነት ውስጥ በማስገባት የግል አላማቸውን ማሳካት የሚፈልጉ ጠላቶች ቡዙ ሲሰሩ ይታያል የኛ አቋም የኛ እትዮዺያዊያን ፍላጎት ደግሞ እትዮዺያ ከማንም ጋ ጦርነት ውስጥ መግባት አትፈልግም በተለይም ከጎሮቤት አገሮቻችን አምነው መቀበል ያለባቸው ማንንም ሳይሆን በአለም አቀፍ ደረጃ ያለው እትዮዺያን ለመውጋት በጦርነት ለመውረር ቀርቶ የእትዮዺያን ሰላም የማስከበር ሀይማኖታዊ ጊዴታ ሃለበት ጎሮቤት አገሮቻችን ሙስሊም ናቸው የሀይማኖት አባቶችን በመጨመር ሁሉም ነገር በንግግር ይስተካከል የመህበራዊ ሚዲያ ወሬ ማንም አይከተል ከሀይማኖት አባቶች ጋ በመሆን እትዮዺያ ላይ ማኒኛውንም ዲንበር ያለፊ ነገሮች ሲከሰቱ በንግግር መፈታት ኣለበት ሁልጊዜ ለችግሮቻችን መፍትሄ መሆን ያለበት በንግግር በሰላማዊ መንገድ ማስተካከል የተመረጠ ይሆናይ ጦርነት አስፈላጊ አይደለም ጦርንት ውስጥ ሚንገባው እንቢተኛ ጠላትን ለመከላከል ስንገደድ ቢቻ ነው በጉልበት በጥበብ በሁሉም የኦፖሬሽን ብቃት ጠላትን ከመከላከል በቴክኒክ መልሶ እስከ ማጥቃት የጠላትን አየር ሀይል በቀላሉ ከአገልግሎት ውጪ በማድረግ አፈር ውስጥ ያለውን ጠላት በአንድ የመነፂር እላማ ሳይሆን የየጠላት አቀማመጥ የእላማ እስትራቴጄ አስቀድሞ በመገንዘብ በእላማ መምታት ሁሉንም የውጊያስልት በማዘመን በስራ ላይ በመተግበር የማይናቅ ሀያላን ከተባሉ አገራት ተርታ መሆናችንን ማንም አይዘንጋ ነገር ግን እትዮዺያ ጠንካራ ና ሀያል እንዳትሆን ተለይቶ ከሚሰራው ሴራ ኣንዱ ለሚሳሌ እትዮዺያ በሙስሊሞች ጦርነት ከፈተች በማለት ሙስሊሞች እንዲያኮርፊ ከመንግስት እንዲጣሉ የማድረግ ፖሎቲካ አገር ውስጥ ሚገኙ ጠላቶች ኣንዱ እግራቸው ኣንዱ ጆሮኣቸው ውጭ ሀገር ነው ያለው ከውጭ ጠላት ጋ የቀራው አካላቸው በአገራችን ውስጥ ስራውን ይሰራል ስለዚህ ከማንም ጦርነት አንፈልግም ስንል ቁጭ ብለን እንወረራለን አገራችንን እናስወርሳለን ማለት አይደለም በክብር ደረጃ በስልጣኔ ሚዛን ሚናስቀምጠው አቋማችን እትዮዺያ አገራችን ከማንም ጋ የመዋጋት ፍላጎት ይላትም እትዮዺያ ለራሳ ሚትፈልገውን ዘላቂ ሰላም ለአለም ትመኛለች እትዮዺያ አለም የደረሰበት የእድገት ደረጃ መድረስ ትፈልጋለች እትዮዺያ ከልመና ከከረዲት ብድር ከችግር ደህንነት ማነቆ ለመላቀቅ ያላትን ተፈጥሮኣዊ መብቶቻን በተጠና በተነበበ በሰለጠነ ማንንም በማይጎዳ መንገድ ትጠቀማለች እትዮዺያ ከችግር ነፃ ለመውጣት ሂጋዊ መንገድ ትከተላለች እንጂ ማንንም የማስፈቀድ ግዴታ ይለባትም እትዮዺያ ያላትን ተፈጥሮኣዊ ሀብቶቻን በአግባቡ ለመጠቀም የሰለጠነ አስተሳሰብ ትከተላለች ለተመሳሳይ ጢያቄዎች ትክክለኛ መልስ በካርታዋ ላይ አስፍራለች ማንንም አንነካም ማንም አይንካን ሰላማችን መከባበራችን መቀጠሉ ትልቅ ስልጣኔም ለውጥም ነው ሁሉም ያስከብረው እንከባበር በመከባበር ትርፍ ኣላ ለጋራ ሰላም በጋራ እንቁም ህግ ይከበር ድንበራችን አገራችን ህዝባችን ሉኣላዊነታችን ይከበር እኛም እናከብራለን:: እትዮዺያ ቅያሪ የሌላት የጋራ አገራችን', 'sentiment': 'negative'}
# {'comment': 'ብቻዬን በቀር እንኩዋን ደጋፊክ ነኝ', 'sentiment': 'neutral'}
# {'comment': 'ብቻዬን በቀር እንኩዋን ደጋፊክ ነኝ', 'sentiment': 'neutral'}
# {'comment': 'የኔ መሪ', 'sentiment': 'neutral'}
# {'comment': 'መሪዬ እወድሀለሁ አብራችሁት በመቆም የኢትዮጵያን ትንሳኤ ለማብሰር ደፋ ቀና የምትሉ ሁሉ እጅግ አከብራችኃለሁ። በርቱ ከጎናችሁ ነን።', 'sentiment': 'positive'}
# {'comment': 'ዋው ውጭ አገር ያየንው ደሰ ሲል እችናት < ="', 'sentiment': 'neutral'}
# {'comment': 'መሳይ አሳማ አዳርጋቸው የሻቢያ ገረዶች ሌሎቻሁ ፋሲል ሰገጤ አዳምጡ ዶክተር አብይ ምን ለኢትዮጵያ እየሰራ እንዳለ አንተ እናንተ አግዳሚ ላይ ተዘፍዝፈህ ወሬ አሉባታ ውሸት እየወጣችሁ ተቀደዱ አጭበርባሪ ሁሉ', 'sentiment': 'negative'}
# {'comment': 'እኔ አንዳንዴ ስለ የት ሀገር አገልግሎት እደሚያወሩ ግራ ይገባኛል እኛ የማናቀው አገልግሎት ሚሰጥበት ቦታ አለ ወይ ስቃይና እንግልት የሌለበት', 'sentiment': 'neutral'}
# {'comment': 'ምን አይነት መሪ ነው ያለን አሁን ገና መኖርን ጀመርን አሁን ወደ ሀገራችን ገብተን ከሰደት መሠራት እንችላለን እድሜ ከጤና ይስጠው መሪያችን', 'sentiment': 'neutral'}
# {'comment': 'ይገርማል!!!በየቀኑ መመረቅ መመረቅ መመረቅ። ተባረክ አብቹ።', 'sentiment': 'neutral'}
# {'comment': 'ግሩም ነው በርቱ ሳይንሳዊ በሆነ መንገድ ሙስናን ማስቀረት ይሉሀል ይህ ነው ቦታዉን የሚመጥን ሰው እንደምታስቀምጡም ተስፋ እናደርጋለን', 'sentiment': 'positive'}
# {'comment': 'አብቹ ከኔ አመራሩ ጀግና ነው በርታልን!! ገቢዎች ስቃይ ናችሆ !!!', 'sentiment': 'positive'}
# {'comment': 'ስለ ጥረታችሁ እናመሠግናለን።ግን የማልስማማው ነገር የኢትዮጵያ ሙስና ግራንድ እንጂ ፒቲ አይደለም። ብልጽግና ሆይ ዋነኛዉ ጠላትህ በዉስጥህ ያለዉ ኮራፕሽን ነዉ። ጨዉ ሆይ ለራስህ ስትል ጣፍጥ አለበለዚያ', 'sentiment': 'negative'}
# {'comment': 'ናዝሬት ማለትህ ነው? መጋኛ ያድምህ!', 'sentiment': 'neutral'}
# {'comment': 'ግሩም ዜና (ዘገባ) መንግስትን የምጠይቀው የህዝብን ንብረት የሚያበላሽ የሚሰርቅ የህዝብ እንቅስቃሴን የሚያውክ ሌቦች እና ማጅራት መቺውን ከ20 ዓመት እስከ ሞተ ቅጣት የሚፍርድ ህግ ካለ ወንጀሉ በጣም ይቀንሳል እላለሁኝ', 'sentiment': 'neutral'}
# {'comment': 'ብልፅግና ሀሉንም በፍቅርና ጠንካራ የፓለቲካ ፓርቲ ሆኖ ሀለሐንም ህዝብ በፍቅር በጠንካራ ህግ አገራችን ቢመራ በወደድን ነበር ግን ብልፅግና ፓርቲ ግን የሚሠራው አንዴ ኃይማኖት ውስጥ አንንዴ ዘር ውስጥ አንዴ የህርስ በርስ ጦርነት ውስጥ ዝፍቅ ህያለ የኢትዮጵያ ህዝብም ግራ እያጋባ 6 ዓመት ሙሉ የህርስ በርስ ጦርነትን ማስቆም አቅጦት የዜጎችን ደም በየቀኑ በመንግስትም በታጠቁትም ሰው ሲሞት ማርቆም ካቃተው ሠላም መፍጦር ሲያቅተው ትንንሽ አገሮች ሲንቁን ትከሻ ሲለካኩ ማየት ያማል ኤርትራም አሰብን በውድ ወይም በግድ መመለስ አለባት ጅቡቲም ከኢትዮጵያ በፈረንሳይ ሸር አገር እንድትሆን የፈበዱላት በገዷ ቀይባህርን 130 ሚሊየን ህዝብን ለማስራብ ግብፅጋ ስትሄድ መምታትና ማስጨነቅ ይቻል ነበር ግን ምን ያረጋል ሚሪሆቹ በቅንነት በፍፁም ኢትዮጵያዊነት ህዝቡን ወደሠላም ቢያመጡት የባህር በር ማግኘት የምችልበት ጊዜና 60 ዓመትየህውሐትና የሻቢያ ሴራ የሚሠበረው ጌዘው አውን ነበር እነ አብይም ከፓስተር ነትና ሁሉንም ጴንጤ የማድረግ ዓይነት አካኤድ ትቶ አንድነት ላይ ቢሠራ ይሻለዋል', 'sentiment': 'negative'}
# {'comment': 'ጥሩ ስራ ነው', 'sentiment': 'positive'}
# {'comment': 'ማንም ምን ቢል ትክክለኛ የኢትዮጵያ ጊዜ ነው። ኢትዮጵያ ልጅ አገኘች።', 'sentiment': 'neutral'}
# {'comment': 'ሞሰብ ሌማት ሰፌድ ትሩፋት ምድር ምናምንቲም ባለጌ ድግምተኞች ምን ታአምር ቢያሳዩ እንኩን እድሳት ይቅርና ማንም አይሰማ።', 'sentiment': 'neutral'}
# {'comment': 'ክቡር ጠቅላይ ሚኒስትር <>የሚሰሙኝ ከሆነ ጌታቸው አሰፋን ወደ ቀድሞ ስራ ይመለስልን ሼኔና ፋኖን ቆለጣቸው ላይ ሃይላንድ ያንጠልጠልልን አሁንስ መረረን<>።።።።።።<>ያለ ጌቾ አሰፋ ባዶ ነው', 'sentiment': 'neutral'}
# {'comment': 'ቃል በተግባር የለውን ያደረገ ኢትዬጲያ ውስጥ ከነበሩት መሪዎች እጅግ የተለየ መሪያችን እናመሰግናለን', 'sentiment': 'neutral'}
# {'comment': 'ይጀመራል ያልቃል ይመረቃል ።ሌላ የቀጥላል ...ሰላም ልማት ክብር ለሀገራችን<>ጤና እና ረጅም እድሜ ለአብቹና በቅንነት አብረውት ለምሰሩ ሀገር ወዳዶች ።', 'sentiment': 'positive'}
# {'comment': 'በጣም የሚደነቅ ሥራ ነው ! እዚህ አውሮፓ የምንገለገልበትን የዕውቀት ደረጃ ለኢትዮጵያ በማበርከታችሁ እናመሰግናችኋለን ፤ ተባረኩ !<>', 'sentiment': 'neutral'}
# {'comment': '120 ሚልየን ጉዳን አደለን', 'sentiment': 'neutral'}
# {'comment': 'ገና ነው ቀጥል ፈጣሪ አብሮህ ነው!!!', 'sentiment': 'neutral'}
# {'comment': 'አብቹ<>ኢትዮጵያ ለዘላለም ትኑር', 'sentiment': 'neutral'}
# {'comment': 'እናመሰግናለን አቢቹ የኛ ዉድ መሪ', 'sentiment': 'neutral'}
# {'comment': 'ከዚህ ድራማ ሚደብረኝ የመገቢያ ሙዚቃው !!', 'sentiment': 'neutral'}
# {'comment': '<>ጌታችን አምላካችን መድሃኒታችን ኢየሱስ ክርስቶስ የሁላችንም ህይወት የአለም ቤዛ ነው', 'sentiment': 'neutral'}
# {'comment': 'ሰላም ዉዶቻቺን', 'sentiment': 'positive'}
# {'comment': 'አስተላለቁ ስሜት አይሰጥም', 'sentiment': 'neutral'}
# {'comment': 'በስዬዬዬዬ ትችላለህ', 'sentiment': 'neutral'}
# {'comment': 'በስቱ በጉ ወይኔ በሳቅሆ', 'sentiment': 'neutral'}
# {'comment': 'ተኩላ እና በጉ', 'sentiment': 'neutral'}
# {'comment': 'ካመናቹ ትድናላቹ ሁዓ ሁዓ', 'sentiment': 'neutral'}
# {'comment': 'እናንተን ሳይ ትዳር ያምረኝል አልህምዱሊላሂ በቅረቡ ላገባ ነዉ', 'sentiment': 'neutral'}
# {'comment': 'በጣም የሚገርመው ነገር ማህበረሰባችን ከመሳቅ ውጭ ምንም አስተውሎ ሊገነዘብ አልሞከረም። ይሔ ሲትኮም ወይም ተከታታይ ድራማኮ ባንድም ይኹን በተለያየ መልኩ የወንድን ክብር እየነካ ነው ያለው ለምንድነው ችላ የተባለው? ለወንዶች የሚሰጠው ገጸባህሪያ( ) የሞኝ, አላማ የሌለው, ዝምብሎ የሚኖር, በሴቶች የሚመካ, ጠጪ ወይም ሱሰኛ ተደርጎ ነው የሚሳለው በተቃራኒው ደሞ ለሴቶች የሚሰጠው ገጸ ባህሪይ ደግ, ብልኽ አስተዋይ አላማ ያላት, ወንድን የምትንቅ, ካለ ወንድ ምንም ነገር ማድረግ እንደምትችል ባጠቃላይ ሴቷን ንጹህና ቅዱሰ አድርጎ ነው የሚስለው ይሔ ድራማ ቆይ ለምን ብሎ የሚጠይቅ አካል የለም ማለት ነው??? ሚዲያውስ ቢኾን አለማው ምንድነው ወንድን ክብሩን ሲያጣ ምንድነው የሚጠብቀው?? በቃ ዝምብሎ መገልፈጥ ነው?? እስቲ ቆም ብለን እናስብ ዳይሪክተሩም ኾነ ደራሲው ምን አይነት አስተሳሰብ ቢኖራቸው ነው ሴቶችን እያሞገሱ ወንዱን ደሞ እያረከሱ ድራማ የሚሰሩት???', 'sentiment': 'positive'}
# {'comment': 'ባል እና ሚስት እንዲህ ግልፅ ሆነው ሲግባቡ ደስ አይልም ዛሬ አላጃጃላችሁትም', 'sentiment': 'neutral'}
# {'comment': 'ሆሆሆ', 'sentiment': 'neutral'}
# {'comment': 'በጣም ያስፈራል', 'sentiment': 'neutral'}
# {'comment': 'መልአኩ ቅዱስ ገብርኤል ከክፉ ሁሉ ይጠብቃችሁ', 'sentiment': 'neutral'}
# {'comment': 'በስንቱ፡ አንድ ነገር ብሆን ካንተ ራስ አልወርድም<>ገለታ፡ አታጓጓኝ', 'sentiment': 'neutral'}
# {'comment': 'ሰላም አቶ አብርሃም ፁሁፍ ነበረኝ በስንቱ ላይ የሚይተኩር 5ክፍሎች እንድ እድል ብትሰጠኝ ብየ ነዉ', 'sentiment': 'positive'}
# {'comment': 'የዛሬው ሀሪፍ ሀሪፍ ሀሪፍ ሀሪፍ', 'sentiment': 'neutral'}
# {'comment': 'ደስ ስትሉ አስተማሪዎቼ ናችሁ ።', 'sentiment': 'neutral'}
# {'comment': 'ክርስቶስ ተንሥአ እሙታን<>በዐቢይ ኀይል ወሥልጣን<>አሰሮ ለሰይጣን<>አግአዞ ለአዳም<>ሰላም<>እምይእዜሰ<>ኮነ ፍስሐ ወሰላም።', 'sentiment': 'neutral'}
# {'comment': 'ሆሆሆ', 'sentiment': 'neutral'}
# {'comment': 'ይቺ ልጅ ግን ትመቸኛለች ፖሊስ ሆና ትሰራ ነበር', 'sentiment': 'neutral'}
# {'comment': 'ዛሬስ ትንሽ ሞዘዝ አላችሁ', 'sentiment': 'neutral'}
# {'comment': 'ሆ ሆ', 'sentiment': 'neutral'}
# {'comment': 'ሒሩት አንቺም', 'sentiment': 'neutral'}
# {'comment': 'ንስሃ ግቡ !!!', 'sentiment': 'neutral'}
# {'comment': 'ምርጦች', 'sentiment': 'neutral'}
# {'comment': 'ሂሩት የተዋጣላት ስው ነው ድንቅ ብቃት ያላት በርቺ', 'sentiment': 'positive'}
# {'comment': 'እስኪ ሚስቴ የምትሆኚ ወዬ በይኝ', 'sentiment': 'neutral'}
# {'comment': 'እስኪ ሚስቴ የምትሆኚ ወዬ በይኝ', 'sentiment': 'neutral'}
# {'comment': 'ኣህለን ጄሪ', 'sentiment': 'neutral'}
# {'comment': 'ገለታ እና ሙሉቀን የምር በጣም ይመቹኛል', 'sentiment': 'neutral'}
# {'comment': 'ቤስ እረሣሀኝ', 'sentiment': 'neutral'}
# {'comment': 'እንኳን አደረሳችሁ በፍቅር', 'sentiment': 'positive'}
# {'comment': 'እዉነትም ሆሆሆየሳቅምጪ መሲና ሂሩቴ', 'sentiment': 'neutral'}
# {'comment': 'ወለሂ ከሳሪስ ስትል ሰሪስ ትዚ አለችኚ', 'sentiment': 'neutral'}
# {'comment': 'ፍቅር በዛሌላ ልጅ ልመጣ ይ<>ነዉ በቃ', 'sentiment': 'positive'}
# {'comment': 'እንዳቺ የገባት አራዳ ሚስት ይስጠን', 'sentiment': 'neutral'}
# {'comment': 'አለማየሁ እያደረገ ነው።', 'sentiment': 'neutral'}
# {'comment': 'መቼም ኮመንቶችን መንበቡ አይቀርምና አጋፋሪ ተከተተይ ድራማ ለምን ተቋረጠ ??', 'sentiment': 'neutral'}
# {'comment': 'እኔ ሳዲግ እንደ በስንቱ እሆናለው', 'sentiment': 'neutral'}
# {'comment': 'በስንቱ የደስታዬ ምንጭ', 'sentiment': 'neutral'}
# {'comment': 'አየ በስቴ', 'sentiment': 'neutral'}
# {'comment': 'ከዚህ በኋላ እንድሁ እንዳላችሁ ሁላችሁም ሳትለያዩ አብራችሁ ስሩ በጣም ነው የምትናበቡት ደስይላል አርፍነው በዚሁ ቀጥሉ', 'sentiment': 'neutral'}
# {'comment': 'አይብርሃን ባንክ የሰውገንዘብ የምታግቱ??', 'sentiment': 'neutral'}
# {'comment': 'በስየና ገለታ ሥወዳቸው', 'sentiment': 'neutral'}
# {'comment': 'የእውነት የእውነት ሁላቹም ትችላላችሁ', 'sentiment': 'neutral'}
# {'comment': 'አታጓጓኝ', 'sentiment': 'neutral'}
# {'comment': 'አዎ ዛሬ በጣም አሪፍ ሁናል ግን እሥከመች የወንዱን ቧታ ሤት የሤቱን ቧታ ወንድ ለምን የተውናል????????', 'sentiment': 'positive'}
# {'comment': 'ትከከል ነህ ወድሚ ማነው የሚቱመነው ቦሁኑ ሶእት በጦም ትከከል ነህ።', 'sentiment': 'neutral'}
# {'comment': 'በስዬ በጉ', 'sentiment': 'neutral'}
# {'comment': 'ገለታ ሙሌ በስንቱ ሂሩቴ በየሳምንቱ መዝናኘአዎቼ', 'sentiment': 'neutral'}
# {'comment': 'ገለታ በጣም ነው ሚመቸኝ', 'sentiment': 'neutral'}
# {'comment': 'ሰምአቷ እናቴ ትጠብቃችሁ፮', 'sentiment': 'neutral'}
# {'comment': 'እንዴት እደምወደዉ እራሴ', 'sentiment': 'neutral'}
# {'comment': 'ስወዳቹ', 'sentiment': 'neutral'}
# {'comment': 'የእጦጦዋ ኪዳነምህረት ሁላችሁን ደጇን ለመርገጥ ታድላችሁ', 'sentiment': 'neutral'}
# {'comment': 'አይ ሂሩት', 'sentiment': 'neutral'}
# {'comment': 'የዛሬዉ ይለያልልልል', 'sentiment': 'neutral'}
# {'comment': 'የዛሬዉ ይለያልልልል', 'sentiment': 'neutral'}
# {'comment': 'አሁንስ አስጠላችሁ', 'sentiment': 'neutral'}
# {'comment': 'የዛሪው ልዩ ነው አይ በንቱ', 'sentiment': 'neutral'}
# {'comment': 'አይመቅደስ ከሳሪስ', 'sentiment': 'neutral'}
# {'comment': 'የበስዬ አድናቂዎች እስኪ ደመሩኝ፣ ጀማሪነኝ', 'sentiment': 'neutral'}
# {'comment': 'ገለታውና ሙሌ ሲኖሩ ነው የሚደምቀው', 'sentiment': 'neutral'}
# {'comment': 'ወይኔ በላቸው ዛሬ የማቅደስ ከሳሪስ በሳቅ ገደለች', 'sentiment': 'neutral'}
# {'comment': 'ሙሉቀን አረጄ ሳያገባ የማይበጅ የማይጠቅም።', 'sentiment': 'neutral'}
# {'comment': 'ቤስ', 'sentiment': 'neutral'}
# {'comment': 'መሬም ቆንጆ', 'sentiment': 'positive'}
# {'comment': 'ሆ', 'sentiment': 'neutral'}
# {'comment': 'የኪዳንምህረት ወዳጁች እንኳን አደረሳቹ ወቹ ከመቅረት ትጠብቀን', 'sentiment': 'neutral'}
# {'comment': 'ስወዳቹ', 'sentiment': 'neutral'}
# {'comment': 'አንዳንድ ሰዎች የአለምን ቤዛ እነሱ ብቻ የሚያቁት የነሱ ብቻ ይመስላቸዋል ክርስትና መኖር ነው ኑሩት እናንተ ባሰብኩት ድንጋይ አፍ አውጥቶ ጌትነቱን ይመሰክራሉ <><>የተመረጠ ሰው ነው የሚድነው የኔ አባት በልመና አይመለክም', 'sentiment': 'neutral'}
# {'comment': 'ተኩላ ካለ በግ አለ ሀሀሀሀሀሀሀሀሀሀሀ', 'sentiment': 'neutral'}
# {'comment': 'ዛሬ በጣም ነዉ ያሳቃችሑኝ', 'sentiment': 'neutral'}
# {'comment': 'ድስ ሚል ቤተስብ ነው እውንት መከባበር እና ፈቅር ትልቅ ነው', 'sentiment': 'positive'}
# {'comment': 'በሴ የመሲ ፈስ ፕሮቲን አለውንደ ??ፋፋክ', 'sentiment': 'neutral'}
# {'comment': 'ከብዙ ጊዜያት በኋላ ድራማው ዛሬ አሪፍ ሆነ', 'sentiment': 'positive'}
# {'comment': 'መቸ ነው የሚፈፀመው ግን', 'sentiment': 'neutral'}
# {'comment': 'በስንቱን የሚትወዱት በላይክሆሆሆሆ ብላ ሔደች', 'sentiment': 'neutral'}
# {'comment': 'እኔ ምለው የሽሜው የጣት ምልክት ምንድነው የገባቹ ካለ ንገሩኝ', 'sentiment': 'neutral'}
# {'comment': 'ዴምሩኚ ቅመሞችየ አንጨካከን አብረንእንለወጥ እንዴግ', 'sentiment': 'neutral'}
# {'comment': 'የምንግዜም ምርጡ በስንቱ', 'sentiment': 'neutral'}
# {'comment': 'በስንቴ', 'sentiment': 'neutral'}
# {'comment': 'ደስ የሚል ያበደ አጨራረስ', 'sentiment': 'positive'}
# {'comment': 'በክርስቶስ ኢየሱስ ያሉት አሁን ኵነኔ የለባቸውም።<> — ሮሜ 8፥1', 'sentiment': 'neutral'}
# {'comment': 'እረ በሴ እጅህን አንሳ። ማቀፍ ክልክል ነው', 'sentiment': 'neutral'}
# {'comment': 'አሪፍ ነው በሳምንት 2 ቀን ይሁንልን', 'sentiment': 'positive'}
# {'comment': 'ደምበኞች እያዳመጠ ነው በስንት ጊዜ ጀምሮ', 'sentiment': 'neutral'}
# {'comment': 'ቤስ', 'sentiment': 'neutral'}
# {'comment': 'ወይኔ', 'sentiment': 'neutral'}
# {'comment': 'እንኳን ደህና መጣችሁ', 'sentiment': 'neutral'}
# {'comment': 'ኢየሱስ ያድናል', 'sentiment': 'positive'}
# {'comment': 'ከኬኒያ በቀር ዙሪያችን ያሉ ጎረቤቶች ጤናማ አይደሉም', 'sentiment': 'neutral'}
# {'comment': 'ኣስቀሩት ወራሪዎች።', 'sentiment': 'neutral'}
# {'comment': 'ጉራ ብቻ! !', 'sentiment': 'neutral'}
# {'comment': 'ኤርትራን ወደ እናት ሀገሯ መመለስ ብቻ መፍትሔው', 'sentiment': 'neutral'}
# {'comment': 'የባህር በር ለማግኘት መጣር ማለት እየተዘዋወሩ ሁሉንም መተንኮስ አይደለም', 'sentiment': 'negative'}
# {'comment': 'የልብ ልብ የሰጧቸው የኦሮሞ ዘረኛ ፖለቲከኞች ናቸው', 'sentiment': 'neutral'}
# {'comment': 'ኢትዮጵያ ውስጥ የተዘገዘጉትም የጎረቤት ሃገራት ስደተኞች መውጣት አለባቸው ። ከ350መቶ ሺ በላይ በ የተመዘገቡ የኤርትራውያን ስደተኞች በኢትዮጵያ የስደተኛ ካምፕ ውስጥ አሉ : የሱማሊያ ስደተኞች ደግሞ . 700ሺ አሉ ። አይንን ያጠፋ አይኑ ይጥፋ ። ባጎረስኩኝ እጄን ተነከስኩኝ ማቆም አለብን ።', 'sentiment': 'neutral'}
# {'comment': 'ውነት ነው', 'sentiment': 'neutral'}
# {'comment': 'ኢትዮጵያ የምትባል ሃገር ማፍረስ ያለባት ሃገር ናት', 'sentiment': 'neutral'}
# {'comment': 'ዉሸታም ታርኩን በደንቢ ተማር ቅድምያ', 'sentiment': 'neutral'}
# {'comment': 'ሠርተው፣ለፍተው ደክማ የማታገኝ፣በምግብ አቅም ከኛ የሚጫንላት ሠነፍ ሐገር፣', 'sentiment': 'neutral'}
# {'comment': 'ምኞትህ ለኢትዮጵያ ጥሩ ምኞት ቢሆንም ያልሆነ ነገር ውሸት አትንገረን ያልተደረገ ያልተፈጠረ አታውራ', 'sentiment': 'negative'}
# {'comment': 'ማትነቁ ማሃይሞች ። ከፍላቹህ መጠቀም ኣለ ይሄን ማወቅ ኣለባቹህ ።', 'sentiment': 'neutral'}
# {'comment': 'ያማል!<>ኢትዮጵያ ትቅደም!!!', 'sentiment': 'neutral'}
# {'comment': 'ሲያምርህ ይቅር መስሎሀል ወገኛ<>የ አሰብ ወደብ ኤርትራን ደምስሼ<>ወደብ በሀይል እቆጣጠራለሁ ብለህ ስትቀደድ<>ከርመህ እሱም ሲከሽፍብልህ ወደ ጅቡቲ ዞርክ???<>የጫት ቤት ቀደዳ ደስ ይላል <>የሶማሊላንድ ወደብ የት ደረሰ????<>አባ መቀደድ', 'sentiment': 'neutral'}
# {'comment': 'ርዕስህና የምትዘበዝበው ይለያያል ሁለተኛ ድርሽ አንልም', 'sentiment': 'neutral'}
# {'comment': 'ይህ የብሄር ፖለቲካ የሀገሪቱን ሀገራዊ አርበኝነት ስሜት በመሸርሸር በምንአገባኝነት ሁሉንም የአገሪቷን ድንበር ያሳጥናል።', 'sentiment': 'neutral'}
# {'comment': 'ጂቡቲ የወደፊት እድልዋን አስልታ ካሁኑ ማግኘት የምችለውን ልሞክር ያለች ይመስላል::<>የንቀት ንቀት::', 'sentiment': 'neutral'}
# {'comment': '220 ሚልዮን አለን', 'sentiment': 'neutral'}
# {'comment': 'ትክክል', 'sentiment': 'positive'}
# {'comment': 'አትፍሩ ጨክናችሁ ወሥኑ። ሥንቴ ሥታሠቃየን ትኖራለች።', 'sentiment': 'neutral'}
# {'comment': 'ይሄ የ ብልፅግና ዲፕሎማሲ ውድቀት ነው ምን ይድረግ', 'sentiment': 'negative'}
# {'comment': 'መለፍለፍ ብቻ። ለዚህ ሁሉ ያበቃን ማን እንደሆነ የምንረሳ አይምሰልህ!', 'sentiment': 'neutral'}
# {'comment': 'አሰብም ዱሜራም ጅቡቲም የአፈር ምድር በህር ነው የወደቡ ጉደይ ገብስ ነው ኢትዮጵያ አሰብን ከአያዛች አፈር አሰብን ታቆጣጣራ ጅቡቲንም አፈር ማልሶ የጅቡቲ ስልጣንም ይቆጣጣራል አፈርና ኢሳ ሶማልን በኢትዮጵያ ምድር ስታዋገ ከርማለች ቁልፉ በአፈር እጅ ነው ኢስማኢል ኡማር ጌሌ እራሡ ይዋጣል ከሞቅድሾ ያበቡር ማስመር ታካትለው ነው ጅቡቲ ያገቡት ሥራ ፈለግ ነበሩ ፈራንሳይ ነት ሰው ያደራገችው ያጊዜ ጉደይ እንጅ አገሩ ያአፈሮች ነው ጫካ ገብቶ ያምዋገ ፉሩድ የጅቡቲ ነፃ አውጭ የቃይበህር ነፃ አውጭ እያማጡለት ነው ከኢስማዕል ቦሐለ የአፈር ፒሬዝደት ይሾማል ከኢሳያስ ቦሐለ በአሰብ ያአፈር ፒሬዝደንት ይሾማል,,,ቁልፉ በአፈር እጅ ነውከአፈር', 'sentiment': 'neutral'}
# {'comment': 'ምከረው ምከረው እምቢ ከለ መከራው ይመከረው ይባላል። <>ጀቡቴ==የቆጡን አወርዳለሁ ብላ የብብቷን ጣለች አይነት ናት።', 'sentiment': 'neutral'}
# {'comment': 'ስራ ፈት ነህ', 'sentiment': 'neutral'}
# {'comment': 'የበሻሻ ልጅ ውሻ', 'sentiment': 'neutral'}
# {'comment': 'ኣንበሶች ግብጽና ጁቡቲ', 'sentiment': 'neutral'}
# {'comment': '&;እኝኝኝችም... እኝኝኝችም ... እኝኝኝችም &; ገልጃጃ ልፋጫም።', 'sentiment': 'neutral'}
# {'comment': 'እዉነትም ኢትዮጵያ ደህና ጎረቤት አልታደለችም', 'sentiment': 'neutral'}
# {'comment': 'እኔመንግስት ብሆን ሳልከፍልነው የምጠቀመው እምቢካለች አጠፋታለሁ', 'sentiment': 'neutral'}
# {'comment': 'እፈር ወራ አታቅም አትበል ለኤርተራ ማነው የወረራት ኢትዩጵያ ቡዳ ሀገር ናት ።', 'sentiment': 'neutral'}
# {'comment': 'አቀራረባችሁን አስተካክሉ', 'sentiment': 'neutral'}
# {'comment': 'ፈጣሪ ሆይ ኢትዮጵያ ልጆች ያላችሁበት ሁሉ ተብቃይን', 'sentiment': 'neutral'}
# {'comment': 'እነቴ ሀገሬ ሁሌሚ አይዞሺ ጌታ ከንቺ ጋሓረ ነው', 'sentiment': 'neutral'}
# {'comment': 'እኛ ኢትዮጵያን ሃገራችንን ዝቅ አድርገን ያዎረድናት እኛው እራሳችን ነን ለምን ዛቻ እናበዛለን ለምን ኢትዮጵያም መብት አላት ወደብ የማግኝት ስለዚህ ልክ ዜጎቻችንን ሲወጡ መብራትና ውሃውንም ማቋረጥ አለበት ።ከዛ ደግሞ ገረፍ ገረፍ ማድረግ ይህንን ካላደረግን ልመና ነው የሚመስልብን', 'sentiment': 'neutral'}
# {'comment': 'ጂቡቲ ዛሬ ኢትዮጵያውያንን እንዳባረረች ነገ ለምና ለመመለስ እንደምትጥር ምንም ጥርጥር የለም።ለጂቡቲ ድንፋታ ለማስተንፈስ የአፋር ክልል ብቻ በቂዋ ነው።ሕዝቧ ለአንድ ወር ጫት ቢቋረጥበት ፕሬዚደንቷን ኦማር ጊሌን በአጭር ጊዜ ውስጥ ከሥልጣን እንደሚያባርር ግልጽ ነው።', 'sentiment': 'neutral'}
# {'comment': 'ኢትዮጵያ በሯን ጥርቅም አድርጋ ብትዘጋ መሄጃ የላትም!ሌላው ቀርቶ ጫት', 'sentiment': 'neutral'}
# {'comment': 'ኢትዮጵያ የሩሲያ ምሣሌ በመውሰድ ጁቡቲን መውረር ያስፈልጋል። ኢትዮጳያዊያን ጁቡቲ አገራቸው ስለሆነ መውጣት የለባቸውም በዚህ ምክንያት ነዋሪዎቿን ደህንነት ለመጠበቅ ተብሎ ጦሯን ማስገባት ይኖርባታል።', 'sentiment': 'neutral'}
# {'comment': 'ኢትዮፕያ ስትወር እንጂ ኢትዮፕያን ድንበር የደረሰ ማንም ኣልነበረም የለምም።ፋሺሽቶች!!', 'sentiment': 'neutral'}
# {'comment': 'ዳጎስ ያለ ብር ለክራይ የሚከፍሉ ፈረንሳይ ቻይና አሜርካ እና ሌሎችም ያደጉ አገሮች በዶላር እሚከፍሉ እያሉ እየተጫቃጨቀች የምትከፍል ኢትዮጵያ ትቅርብን ቢሉ እሚጎዳይ ድሀው ማህበረሰብ እንጂ ጨቅላው መሪና ሚኒስተሮች ተጨማሪ ሀብታሞች በቦይንግ ያስልካሉ ይብላኝ ለድሀው ሁለት ሞት ይሞታል ዋናው ቁምነገር ከጎረቤቶች ጋር ተስማምቶ መኖር ካልሆነ አሽቀንጥረው ይጥሉሀል በመሳርያ ማንንም ማንበርከክ አይችልም እንኳን የድሀ ድሀ ሀገር ኢትዮጵያ አሜርካም አፍጋኒስታን ሄዳ ምንም ማድረግ አልቻለችም', 'sentiment': 'neutral'}
# {'comment': 'ጂቡቲ የኢትዮጵያ ግዛት የነበረች ፈረንሳይ በረቀቀ ዘዴ 99 ዓመት የተጠቀመችባት ግዛታችን ነበረት። ደርግ በኤርትራ በነበረበት ጦርነት ጊዜ በማጣት ያልተረከባት አገራችን! ስለዚህ ወደ እናት አገሯ የምትቀላቀልበትን መንገድ ማጤን ይገባል።', 'sentiment': 'negative'}
# {'comment': 'አገሬ ኢትዪጲያ ሁሌም እወድሻለው ደሜን ለአቺ እሰጣለው', 'sentiment': 'neutral'}
# {'comment': 'የትቋቋመ ሸንተማ ደሲሳ የተባለ አበሻ የዛሬ 3000 ዓመት ይኖርበት እንደነበረ የታወቀ ነዉ. ይሄን የተጣራ ሓቅ ይዘን ብንሄድበት. ሊሂቃን በፋና ቢሄዱበት እላለሁ', 'sentiment': 'neutral'}
# {'comment': 'ላም ኣለኝ በሰማይ፡ወተትዋን ኣላይ።', 'sentiment': 'neutral'}
# {'comment': 'ጉራ በቻ ዝም ብላችሁ በገዛ ጉራችሁ ሙቱ.። ቃላት ለ ነፋስ ብቻ. ልመና ሃላቀር መጥፎ ሃሳብ ቀረርቶ ብቻ።', 'sentiment': 'negative'}
# {'comment': 'ፈረንሳይን ያመነ ወየው ግብፅ እንኩአን የታወቀች ናት', 'sentiment': 'neutral'}
# {'comment': 'ራሱን የጣለ ሰው ሁሉም ያቀለዋል ይሰድበዋል. እንድያ ሆኖ ነው እንጂ ማ ሀገሬ...........', 'sentiment': 'neutral'}
# {'comment': 'ወያኔንና መለስ ዜናዊን እንኳን ደስ አላችሁ በሉልኝ።', 'sentiment': 'neutral'}
# {'comment': 'ጎረቤት ማክበር ባህላችን ነበር', 'sentiment': 'neutral'}
# {'comment': 'ግብፅን ከመረጠች ግልፅ ጠላትነት ነዉ ! ልኳን ማሳየት ነዉ !', 'sentiment': 'negative'}
# {'comment': 'አገራችን እጇ አመድ አፋሽ ሆኖ የቆየበት ምክንያት አለዉ ወይንስ ከባድ እርግማን፠፠፠', 'sentiment': 'neutral'}
# {'comment': 'ይሔ ጣቢያ እስከ ዛሬ የት ነበር ? አቀራረቡ ይመቻል የኋላ ኋላ ካልተጠለፈ', 'sentiment': 'neutral'}
# {'comment': 'ወሬ ብቻ.....', 'sentiment': 'neutral'}
# {'comment': 'አሁን ደሞ ወደ ጁቡቲ ዞራቹ', 'sentiment': 'neutral'}
# {'comment': 'ግብጽ አንደ ዘንዶ አየተጠመጠመችብህ ነው አንተ ጣረሞት ላይ ሆነህ ለፎልፍ', 'sentiment': 'neutral'}
# {'comment': 'ኢትዮጵያ የምትባል ሃገር መፍረስ መበታተን አለባት የካሃዲ የሁዳ ምድር ነች በትግራይ ህዝብ ለይ ግፍና ጭካኔ የዘር ማፅዳት ዘመቻ ፈፅማለች የግዜ ጉዳይ እንጂ ትበተናለች ትፈርሳለች ፈርሳ ማየት ናፈቀኝ', 'sentiment': 'negative'}
# {'comment': 'አሁን ምንድነው የራስን ወደብ ሽጦ መተራመስ ወደብ የሌለው አይኖቹ የጠፉ ና ደካማ ሀገር እንደሆነ ተዘነጋ እንዴ በአሁኑ ጊዜ በዘር ላይ የተመሰረተ ጦርነት ና የምስክኑን ህዝብ ቤት አፍርሶ ማፈናቀል ና አስከፊ ኑሮ ውድነት ባለበት አንድነት ልኖር ይችላል ?', 'sentiment': 'negative'}
# {'comment': 'ቁርበት የሆነ ትንታኔ ያልተማረ መኃይም እንኳ ከዚህ የተሻለ ትንታኔ ይሰጣል። ሌላ ስራ ሰርተህ ብላ። አማራጭ ወደብ እንኳ ቢገኝ የባቡር መስመር መዘርጋት ዓመታት ይወስዳል። በተረፈ ጂቡቲ የባህር ዳርቻዎቿን ለጦር ሰፈርነት አከራይታ በመጠቀም ላይ ትገኛለች።', 'sentiment': 'neutral'}
# {'comment': 'ጎበዝ ጋዜጠኛ ነሕ አቀራረብሕ ደስ ይላል በርታ ።', 'sentiment': 'positive'}
# {'comment': 'እንደ ራሺያና ዩክሬን ጅቡቲን አንድ ቀን ...', 'sentiment': 'neutral'}
# {'comment': 'አብይነቃበልእኛንለኛአታገዳድል', 'sentiment': 'neutral'}
# {'comment': 'ደካማ ትንተና ፤ ጂቡቲ ኢትዮጵያዊ አማራጫ ማጣቷን ፡ ቢገኝም አዋጪነቱ እምብዛም ነው እንደሆነ ታውቃለች ፡ ለዚህ ማሳያ ከሶማሊላንድ ጋር ስትፍራረም እኛ የንግድ ወደብ እንስጣችሁ እስከማለት ደርሰው ነበር ፤ ዛሬ ግን ይህ ሁሉ በእጃችን የለም፤ ወይም አዋጭ አይደለም፤ አማራጭ ቢኖረ ተጨማሪ መሰረተ ልማት መገንባት ግድ ይለናል(ወደ በርበራ፤ ላሙ ወደብ )', 'sentiment': 'negative'}
# {'comment': 'ጅቡቲ መብትዋ ነው በሰው አገር መንጠራራት ከንቱ ነው ውጤት የለውም በብልፅግና መንግስት አተራማሽነት የመጣ ጣጣ በመሆኑ ከመቀበል ውጪ ሌላ አማራጭ የለም መቀበል ነው የአማራ የትግራይ ህዝብ እየተጨፈጨፈ አደለም እንዴ', 'sentiment': 'neutral'}
# {'comment': 'በቃ የኢትዮጵያ ጉዳይ ሊያከትም ነው<>ያሁሉ ግፍ በህዝባቹ ሳይቀር በድሮን የምትጨርሱ ምድረ ርጉማን የጁቡቲ እርምጃ<>ተገቢነው ገና......ገና..ያለ ምንም ጦርነት<>ኢትዮጵያ ጎሮሮዋ ኣይንዋ ጣትዋና ምላስዋ<>ሊቆረጥ ነው.ኣበቃላት ያየኣፍሪቃ ቀንድን ካንሰር የሆነችው ጉረኛ ታሪክ ኣልባ<><>ወ......ደ......ብ.......ኣልባ ...ገና...ይለያል<>ዘንድሮ. የኣፍሪቃ ዩጉዝላብያ ትሆናለች.<>እድሜ ለኤርትራ ግብጽ ሱዳን ጁቡቲ ሶማልያ<>ቀይ ባሕር ታፍሮና ተከብሮ ይኖራል.', 'sentiment': 'negative'}
# {'comment': 'የአህያን ስም አታጥፋ ወንድም !! ከግብፆች አህያ አስር እጅ ይሻላል', 'sentiment': 'positive'}
# {'comment': 'ኤርትራም ጂቡቲም ያጎረሰችውን የኢትዮዽያን እጅ ነው የነከሱት', 'sentiment': 'neutral'}
# {'comment': 'የኢትዮጵያ መሪዎች ህጻን እና መሃይም ናቸው። የእነሱ ያልሆነ ነገር ባለቤት ለመሆን ያልማሉ። ቀይ ባህርን ጨምሮ አዲስ ካርታ እንዲኖራቸው ህልም አላቸው። አብይ ይህን የሚያደርገው ስልጣኑን ለማራዘም እና አማራን ለማሸነፍ ነው።', 'sentiment': 'neutral'}
# {'comment': 'ምንም የሚጠቅም ወሪ አይደለም አገር አይጠቅምም ምን ላውራ', 'sentiment': 'negative'}
# {'comment': 'ሁሌም በየአስር ዓመቱ እንዲህ ታደርጋለች ጅቡቲ ስለማትከታታተሏት ነው። ባለጌዎች ናቸው ርሀብተኞች ሁሉም ነገሮች ከኢትዮጵያ ነው የሚገባላት።', 'sentiment': 'neutral'}
# {'comment': 'ድሮስ <>ዱርየወች፣እንኳን አገር ሊመሩ፣ከብቶችንም፣በስላም፣ አውለው፣ወደ ቦታቸው መመለስ አይችሉ።<> እንዲህ ነው፣የጎረቤትም ህዝብ ያውቃል ደንቆሮ አይደለም።<> አሁን ደግሞ፣ይህን ዱርየ ጅቡቲ ከግብፅ ጋር ሆና፣በዲፕሎማቲክ፣ካርድ፣መዛ፣አይኑን ገጭታ ጨለማ ውስጥ ስታስቀምጠው።<>&; ኢትዮጵያ የወሰደችው፣ጅቡቲን የሚያስቆጣ ድርጊት፤ገንዘብ ሊቀር ነው&;<>ብሎ፣የራስን ቅዠት በሚድያ፣በመደጋገም ጮቤ መርገጥ፣የደናቁቶች፣ጩህት ነው።<><> አብይ አህመድ፣የቁም ወፈፌው እና ፣የውሸት፣አከፋፋዩ፣አሁኑኑ ጥፋ ከኢትዮጵያ።ስለ አንተ እንኳን ኢትዮጵያውያን፣ጎረቤት አገራት ስምህ ሲጠራ እንደሚቀፋቸው፣ይህው ጅቡቲ እንኳን እንድ ስምን ነች።<>መጀመሪያ፣የኢትዮጵያ ስደተኛች ከአገሯ እንዲወጡ ያሳሰበችውን፤አብይ ጊዜ ይራዘምልኝ ብሎ የጠየቃትን፣ጅብቲ ደረቷን ነፍታ በፍፁም ባስቁመጥኩት የቀን ገደብ፣መውጣት አለባቸው፣በማለት፣ምን ያህል ፣ወራዳ እንደሆነ ነግረዋለች።<>ዛሬ ደግሞ፣ወደቧን እንደማይጠቀም፣አሳወቀች።', 'sentiment': 'neutral'}
# {'comment': 'ኢትዮጵያ መሪዎች ከስህተታቸው ከተሞክሮ መማር መጀመር አለባቸው ጂቡቲ ወደብ ተከራየናት በሌላ ምርጫ ስናቆም ጠላችን በተገኘ አጋጣሚ ልትበቀለን ትፈልግም ይሆናል ስለዚህ ጥሩ ጎረቤቶች ጋ የማያዛልቀንን ነገር ባንጀምርና ጠላት ባናፈራ ወደብ የራሳችን የሚሆን መፈለግ ከኤርትራ ጋ በደንብ ተግባብቶ የራሳችንን ፋንታ በሰላም ማግኘት ከተቻለ እሰየው ካልተቻለ እስኪቻል መወያየት ጥቅሙ የጋራ መሆኑን ማሳየት', 'sentiment': 'negative'}
# {'comment': 'ዝም ብለህ አትንበጥረቅ ሱማሉያም ጁቡቲም የኢትዮጵያ ጥሩ ወዳጅ ነበሩ ግብፅን መኖራንም አያውቁም ሱዳን ቦንድ እየገዛች እስካቫተርና ባለሙያ ልክ የህዳሴውን ግድብ ከኛ ጋር ስይሰራ ረበር ግብፅን የማታውቅ ቁልፍ አጋራችን ናት ግብፅ በቀጠናው ተፅእኖ መፍጠር አይደለም በቀጠናው መገኘት አልቻለችም ይህ ሁሉ ኢትዮጵያ ጠንካራ ዲፕሎማሲና የተረጋጋ ፖለቱካ በነበራት ዘመን ነው ዛሬ እንካን ክጎረቤት የራሳችን ህዝብ ጋር እየተዋጋን አገራችን እየወደመ ህዝባችን እያለው እርስ በርስ እየተፋጀን ነው ጣትህን ወደ ሌላው ከመቀሰር የራስን ማየት ነው ጎረቤቶቻችንን እየተነኮስን ስጋት የሆነው እኛ ነን ሱማሌ አንድ አይደለም ሶስት ወደብ ውስዱ እያለች ወዳጃችንን ከድተን ግዛት የሆነውን የሱማሌ ላንድ እናስገነጥላለን ብለን ሱማሌን ያጣ ነው በኛው የዲፕሎማሲ ስህተት ነው በሱዳን ጦርነት እጃችንን አስገብተን ከዱባይ ጎን ቆመን ሱዳንን አጣን ጁቡቲ ወዳጃችንን በምናደርገው የጦርነት ዝግጅት በርግጋ ግብፅን ያዘች ድሮ 90% የምናስገባው የልማት እቃዎች ነው ዛሬ 90% የጦር መሳሪያ ነው ከአርባ በላይ ዩኒቨርስቲዎቻችን የግልና የሙያ ኮሌጆች ምትክ 90% ወጣት ለውትድርናና ለስራ ድህነት ተዳርጓል ጎረቤት አገሮች ይህ እንቅስቃሴዎችን አስግታቸዋል ኤርትራን አምጥተን ህዝባችንን እንዳላስጫፈጨፍን ወደ ኤርትራን ዞረን ጠብቂን አሰብ የኛ ነው አንለቅሽም ስንል ጁቡቲ በረገገች የራሳችንን ጦረኛነትና የዲፕሎማሲ ችግር ሌሎች ላይ አታላክ ወንድም ኢትዮ ፎረምን ስማ እውነትን ታገኛለህ ዝም ብልህ አትቀደድ መጀመሪያ ከህዝብችን ሰላም መሆን ከአንብገነንነትና ከፈላጭ ቆራጭነት ወጥቶ ፖለቲካውን ለሁለም ተጠቃሚ ማድረግ የተወካይ ምክር ቤቱ አባል ደስአለኝ ጫኔ እንዳሉት የጦር መሳሪያና የጦርነት ዝግጅት ቀንሶ ልማት ላይ መስራት', 'sentiment': 'negative'}
# {'comment': 'ጎረቤት ሁሉ ከጠላህ፣መጥፎ ሰው ነህ ማለት ነው።', 'sentiment': 'neutral'}
# {'comment': 'ከንቱ ውዳሴ።', 'sentiment': 'neutral'}
# {'comment': 'ለምን ይዋሻል። የኢትዮጵያ መንግስት የማይታመን ከሃዲ ቃልአባይ ወላዋይ አንዴ ከሱማሌ ወደብ ተስማማው ውሸት። ሰጥቶ መቀበል ምን የሚሰጥ አለሕ። ወደብ በሃይል አይገኝም ምክንያቱም ግብጽ አባይን በሃይል ምውረር ስለማትችል ስለዚ ያንተ ያልሆነውን አትመኝ። ካልሆነ ግን ትበታተናልሕ ኢትዮጵያ ምትባል አገር ነበረች ልባላለሕ።', 'sentiment': 'neutral'}
# {'comment': 'ጉራ ብቻ የአገር ልኤላዉነት እየ ደፈርክ አሸባራዎች ያለ ጦርነት መኖር አትችሉም አህያ በነጻ የሰጠሀዉ የለን ከፍለዉ ነዉ ጫት የሚገዙ አህያ ገና ገና ገና የባብሩ ሀዲድ ይሰበራል', 'sentiment': 'negative'}
# {'comment': 'ሰላም አስከባሪ የምትልከዉ ዶላር ፍለጋ ነዉ በመጀመሪያ የሃገርህን ሰላም አረጋጋ ገለቴ ቡቃ ካቲካላ ስንት ገባ ?', 'sentiment': 'positive'}
# {'comment': 'ተረት ተረት ።', 'sentiment': 'neutral'}
# {'comment': 'ደስ የሚለው መስሚያው ጥጥ የሆነ መሪ ሰቷታል ሀገሬ የራሳችን ወደብ ይኖረናል እቺ ችጋራም ጅቡቲ ወደቧን ታቅፋ ትኖራለች ያኔ ግብፂት መታ ትከራያታለች', 'sentiment': 'neutral'}
# {'comment': 'እንዴት አባክ ሆኖ ነው የወደብ ገንዘብ የሚቀረው?', 'sentiment': 'neutral'}
# {'comment': 'ኢትዮጽያስ ስንዝ ቢኖራት መቸ ከእርዳታ ተላቅቃቹ ታቃላቹ ምደረ ለማኝ ምንቀኞች', 'sentiment': 'neutral'}
# {'comment': 'እሰየው ጁቢቲ ደግ አደረች !!<>የጉሮኞች ሀገር ኢትዮጵያ ቁጭ ፍጥጥ !!<>ባሕር መጠቀም የለ ምን የለ !!<>በደንብ ቃዡ አሁን 4።', 'sentiment': 'neutral'}
# {'comment': 'ላም አለኝ በሰማይ አሉ !<>ወጡ ሳይወጠወጥ ወስከምባው ቂጢጥ አሉ!', 'sentiment': 'neutral'}
# {'comment': 'ለጥቅም ስትሉ እርስ በራሻቹ ምትጨራረሱ', 'sentiment': 'neutral'}
# {'comment': 'እንግዲህ ዋጠው ጂቡቲ ኣትጎዳም ዝም ብላቹ ኣትጫጩ።', 'sentiment': 'neutral'}
# {'comment': 'አትቀደድ', 'sentiment': 'neutral'}
# {'comment': 'ጦቢያኖች ጅል የሆነ ትዉልድ ሰርቶ የሚበላ ጠፋ አዉርቶ አደር', 'sentiment': 'neutral'}
# {'comment': 'ቅዝታም', 'sentiment': 'neutral'}
# {'comment': 'እድሜለገሀነም አሊአህመድ ይህን ፈጻሚው ያ', 'sentiment': 'neutral'}
# {'comment': 'ህዝቤ ሆይ የኔ ትውልድ ሆይ ለሃገርህ እና ለህዝብህ ቆርጠህ ታገል !! ከብሔርና ከጎጠኝነት ውጣ ! አንተ አንቺ የብዙ ታሪክ ባለቤትነህና ታሪክህን ሳታበላሽ ፀንተህ ክብሯን ጠብቅ ተንቀናል ዝቅ ተደርገናል በእርስ በርስ ንክሻ እርስ በርስ መፋጀት ለንቀት ምክንያት አድርጎናል እና በአንድነት ክብራችንን ታሪካችንን እንጠብቅ እላለሁ <>እኔ ወንድማችሁ ከጂቡቲ', 'sentiment': 'neutral'}
# {'comment': 'እቺ አንድ ክፍለ ከተማ የምታክል ሀገር ጭራሹን መጠቅለል ሀሉንም ሁሉንም ስል ወደቡን ዓይደለም ጅቡቲን ከዓሰብ ጋር ነው', 'sentiment': 'neutral'}
# {'comment': 'ምንድነው ጅቡቲን ሚያሳብዳት ቡል', 'sentiment': 'neutral'}
# {'comment': 'የሐያ አመት ወሬ አዲስ አደረከው !', 'sentiment': 'neutral'}
# {'comment': 'ጅቡቲ ነብስሽን አይማረዉ እወቅዉ አንቺ ቅጥረኛ', 'sentiment': 'neutral'}
# {'comment': 'ውሸታም እኛን ቀጂቡቲ ውስጥ የምንኖረውን ጠይቅ ታላወክ', 'sentiment': 'negative'}
# {'comment': 'ኢትዮጵያኖች አስተውሉ እስቲ፤ አገራችንን ጠልተን ብንሰደድም፤ የተሰደድንባቸው አገሮች ሁሉ ጠልተውን ያስሩናል ፣ያሰቃዩናል ይህም ሳይበቃቸው ቀርቶ ያፈራነውን ንብረት ቀምተው ከአገራቸው ያባርሩናል። ከዚህ ሁሉ ለምን እኛ የውጭ አገራት በሚቀናባት በውቧ አገራችን ውስጥ ተሰማምተን፣ አንድነታችንን አጠናክረን፣ ተደስተን እና ተንደላቀን አንኖርም? እግዚአብሔር ለኢትዮጵያ ከሁሉ አስበልጦ የተፈጥሮ በረከትን ሰጥቷል።እኛ ኢትዮጵያውያን ግን ባለማስተዋል ሞኞች እና ተላላዎች ሆነናል። ይህንኑ ባህርያችንን የውጭ ጠላቶች በሚገባ አውቀውት<>ለፍላጎታቸው ማስፈፀሚያነት ይጠቀሙብናል።ቆም ብለን እናስብ የተሳሳተውን መንገዳችንን ትተን ወደሚጠቅመን ትክክለኛ መንገድ እንግባ ። < =" < ="', 'sentiment': 'neutral'}
# {'comment': 'ጅቡቲን አታቃትም ማለት ነው ? ከ13 ሃያላኖች በላይ የጦር ካምፕ የመሠረቱባት ልዑዋላዊ ሃገር በኢትዮጵያ ትተዳደራለች ማለትህ አላዋቂነት ነው።በድሮን ስታተረማምሰን ለምን መልስ አልሠጠንም?', 'sentiment': 'neutral'}
# {'comment': 'አንተ,ዉቨታም,ያልሆነ,ታርክ,ተወራለህ,ምንከኛች', 'sentiment': 'neutral'}
# {'comment': 'በትክክል ገለጽከው', 'sentiment': 'neutral'}
# {'comment': 'የዲፕሎማሲ ክስረት እንጂ ወደብ ተገኝቶ አይደለም ባባ አንዳንዴማ እውነት ተናገር ወንድሜ ለህሊናህ ሆድ ምናባቱ', 'sentiment': 'negative'}
# {'comment': 'ኢትዮጵያ የነካ የለውም በረካ እቺ ሚጢጢዋ ጁቡት ምንዋ ተማምና ነው', 'sentiment': 'neutral'}
# {'comment': 'ኢትዮጵያ በሰጥቶ መቀበል ኣትላንቲክ ውቅያኖስን እንደምትቀበል ትላንትና ዘለንስኪ ከዩክሬን ኣስታወቁ።', 'sentiment': 'neutral'}
# {'comment': 'እኛ አንዴ ፋኖ አንዴ ሸኔ አየተባባልን እርሰበርሰ ሰንባላ ይችን ትልቅ ክብር ያላት ሀገር አዋረድናት እኛ የራሳችንን ሀገር አክብረን ማሰከበር አቃተን በጣም እናሳፈራለን አንድ ሆነን ሀገራችንን ማሰከበር አቃተን አሳፋሪ ትውልድ!!!!!!!', 'sentiment': 'negative'}
# {'comment': '. ኢትዮጵያን የነካ የለውም በረካ!', 'sentiment': 'neutral'}
# {'comment': 'የኢትዮጵያ መይግስት እንደዚህ በዲፕሎማሲውም በሀይልም አቅመቢብና ልፍስፍስ ያረገው ምንድን ነው?', 'sentiment': 'neutral'}
# {'comment': 'አይ ሀገሬ ስንቹ እንዳልቀመሰሽ ማንም ደፈረሽ', 'sentiment': 'neutral'}
# {'comment': 'በዚህ ዘመን ኢትዮጵያዉያን ዉጡ ያልተባሉት ሀገር የለም ክታላቆ እሜሪካ ዕስክ ትንሽ፤ ጁቡቴ፣ ዜጎች ተዋረዱ፣', 'sentiment': 'neutral'}
# {'comment': 'ግብዕን መውቀስ ተወት አጅርግ ና አብይ መንግሥት ኢትዮጲያን ይወዳል? ኢትዮጲያን አፍርሰው በፍርስራቯ ላይ ታላቋን ኦሮሚያ እና ትግራይ ብለው ሁለት ሀገር መሙሥረት ነው ።', 'sentiment': 'neutral'}
# {'comment': 'ኢትዮጲያን ያስናቀው አብይ ነው ።አሁን ደግሞ ከጂቡታጔጋር ልታዋጌን ነው ። ሱማሌያ ና ግብፅ ተባብሩው ሊወጉን ነው ብላችሁ ። ይህን በቀን ሁለተየ ብልት የሜያድር ህዝብ ለጦርነት ቀሰቀሳችሁ። ስርጭት ስለገባው ዝም አለ። ውድ እናስመልሳለን እያላችሁ ከኤርትራ ጥቅም ልንዋጋ ነው ብላችሁ ቀሰቀሳችህ ዝም አላችሁ። ይህንንም ህዝቡ ድጋፉን ሲነሳ በአፍሪካ እጅግ ድካማ የሆነች አገር ዜጎችን አባረሩች ተሳደበች እያላችሁ ከኢትዮጲያ ህዝብ ጋር ለማጣላት ትሞክራላችሁ። የኢትዮ ጲያ ህዝብ በገዛ አገሩ እየተፈናቀሉ፥ቤት ንብረት እየፈረሰ አይደል?ይህ ን ይደንቃል ። አብይ መንግሥት የማይጣላው የጎረቤት አገር የለም እንዴ? ጦርነት አንፈልግም። አብይን እምነት እንኳን ጥር ሜዳ፤ኳስ ሜዳ የግብ የለም።', 'sentiment': 'negative'}
# {'comment': 'ማራኪ አቀራብ ነው', 'sentiment': 'neutral'}
# {'comment': 'ፈጣሪ ℹℹዬ <>🟢🟢🟢🟡🟡🟡🟡', 'sentiment': 'neutral'}
# {'comment': 'አሁን ገና አንድ እኖናለን መንግስት መሳሪያ በአየር ይገባል ፋኖ ተበትኖዋል ህወሓት ሞቶዋል', 'sentiment': 'neutral'}
# {'comment': 'ዋው', 'sentiment': 'neutral'}
# {'comment': 'እውሸታም። እባክህ ለመታየት ታማኝ ዜና ስራ።', 'sentiment': 'neutral'}
# {'comment': 'አየሳኩ ነዉ የሰማሁህ', 'sentiment': 'neutral'}
# {'comment': 'ጥሩ ትንታኔ ነው', 'sentiment': 'positive'}
# {'comment': 'ኢትዮጵያ አሸናፊ ናት', 'sentiment': 'neutral'}
# {'comment': 'ላታመልጪ አታሩጪ', 'sentiment': 'neutral'}
# {'comment': 'ሳለደንቃቹ አላልፈም', 'sentiment': 'neutral'}
# {'comment': 'አሪፍ ነው', 'sentiment': 'positive'}
# {'comment': 'በጣም የወደድኩት ድራማይመቻችሁ ወዳጆቼ', 'sentiment': 'neutral'}
# {'comment': 'ለገምዛም ተሰርቷል ለካ', 'sentiment': 'neutral'}
# {'comment': 'ምናለየገጠር፣ወድማገባ፣ጀግናናችሁ፣ያገሬልጅች', 'sentiment': 'neutral'}
# {'comment': 'መቼም የማልጠግበው ፊልም ባየው ባየው', 'sentiment': 'neutral'}
# {'comment': 'ዋው', 'sentiment': 'neutral'}
# {'comment': 'አውራሪስ ያገሬልጅ አጣዬማጀቴስወዳችውአቃችዋለሁየሰሩትን ፍልምን', 'sentiment': 'neutral'}
# {'comment': 'ካብ ሰራቦይ አለን በሉኝ እሲ', 'sentiment': 'neutral'}
# {'comment': 'ሀገሬ ማጀቴ ክፉሽን አልሥማ', 'sentiment': 'neutral'}
# {'comment': 'አይ ጃራ', 'sentiment': 'neutral'}
# {'comment': 'አገሬ ማጄቴ', 'sentiment': 'neutral'}
# {'comment': 'ምርጽኖ', 'sentiment': 'neutral'}
# {'comment': 'ፊልምብሎዝምነውገጠርውበቴማንነቴ', 'sentiment': 'neutral'}
# {'comment': 'ሀገሬ ዘር ሀይማኖት ሣልል የገጠር ነገር ሁሉንም አወዳለሁ', 'sentiment': 'neutral'}
# {'comment': 'ያግቡኝ', 'sentiment': 'neutral'}
# {'comment': 'ክክክክ', 'sentiment': 'neutral'}
# {'comment': 'ዘነብ ክፍሌ ጓደኛዬ', 'sentiment': 'neutral'}
# {'comment': 'ሸዋ ሀገሬ', 'sentiment': 'neutral'}
# {'comment': 'በጣም ደስ እሚል', 'sentiment': 'neutral'}
# {'comment': 'ልጁን አፈቀርሁቶ', 'sentiment': 'neutral'}
# {'comment': 'ኧረ በደንብ እዩት ሚስጥር ይዟል!!!', 'sentiment': 'neutral'}
# {'comment': 'የመስኖ የማጅቴ ልጆች አላቹህ አለን በሉኝ ሙሉ አንፆኪያ ገምዛ ልጅ አላቹህ አለን በሉኝኝኝኝኝኝኝኝኝኝኝኝኝኝኝኝኝኝኝ', 'sentiment': 'neutral'}
# {'comment': 'የሀገራችን ፍልም እንኳን ድስ አለህ በሉኝኝኝኝኝኝኝኝኝኝኝኝኝኝኝኝኝኝኝኝኝኝኝኝ', 'sentiment': 'neutral'}
# {'comment': 'የገምዛ የሀገራችን ፍልም ዋው ድስ ይላል ይመቻቹህ', 'sentiment': 'neutral'}
# {'comment': 'የማጀቴ ልጅ በመሆኔ ኮራሁኝ', 'sentiment': 'neutral'}
# {'comment': 'ዋውበጣምደስየሚልፊልምእናመሰግናለንዘውዱጀግናነህአድናቂህነኝፈጣሪሆይኢትዮጲያሀገራችንሰላምአድርግልን', 'sentiment': 'neutral'}
# {'comment': 'ነጠጨ', 'sentiment': 'neutral'}
# {'comment': 'ዋው ትክክለኛ የሀገራችን ፊልም ቁርጥ አይ ይሄ ደም መልስ ስንቱን አጫረሰው', 'sentiment': 'neutral'}
# {'comment': 'ተመቻችሁኝ', 'sentiment': 'neutral'}
# {'comment': 'አማራኛ አታበላ', 'sentiment': 'neutral'}
# {'comment': 'ይታወቃል <> ይታወኣል', 'sentiment': 'neutral'}
# {'comment': 'ለሶስተኛ ጊዜ አየሁትዋዉ ሚርጥ ፊልም ነዉ', 'sentiment': 'neutral'}
# {'comment': 'አስተማሪ ፊልም ነው', 'sentiment': 'neutral'}
# {'comment': 'በጣም የሚገርም ትወና ነው ሰላም ለሀገራችን', 'sentiment': 'positive'}
# {'comment': 'የኔዉድ ሀገር ማጀቴ.', 'sentiment': 'neutral'}
# {'comment': 'ዋውውውውውው ነው', 'sentiment': 'neutral'}
# {'comment': 'አርቲስቶቻችንም እሮጠው አማራ ክልል ነው እራሳቼውን የሚያገኙት እንኳንም አማራ ሆንኩ', 'sentiment': 'neutral'}
# {'comment': 'ማጀቴ ማጀቴ ማጀቴ ማጀቴ እፍፍፍፍ ምን ልሁንላችሁ ጀግንነት በፊልም ብቻ አይደለም በተግባርም ነው ይፋት ማጀቴ ይለያል ያባቱ የሚኒሊክ ልጅ', 'sentiment': 'negative'}
# {'comment': 'ጀግና', 'sentiment': 'positive'}
# {'comment': 'አገሬ ስላምሽ ይመለስ', 'sentiment': 'neutral'}
# {'comment': 'የዛሬ አመት እበተሠቦቸ ጋ ነበር ያየሁት', 'sentiment': 'neutral'}
# {'comment': 'ከብዙ አመት በሗላ ነው ደግሜ ያየሁት መሬት ማለት ሀገር መሬት ማለት ሰው ነው ነው እውነት ነዉ አምላኬ ሆይ በሰላም ለናትና ላባቴ በየ ና ቦታ በሰላም አብቃኝ ፣አብቃን አሜን', 'sentiment': 'positive'}
# {'comment': 'የቦታው ማማር ፊልሙ አንደኛ ዋው', 'sentiment': 'neutral'}
# {'comment': 'ሀገራችን ገምዛ ወንዛችን ሳልወዝ', 'sentiment': 'neutral'}
# {'comment': 'ምርጥ ወንድ ተዋናይ ሙሉአለም <>ጉማ አዋርድ', 'sentiment': 'positive'}
# {'comment': 'ዋዉበጣምደስየሚል', 'sentiment': 'neutral'}
# {'comment': 'ማጄቴ ሰሜን ሸዋ ሃገሬ ሰላምሽ ይመለስ', 'sentiment': 'neutral'}
# {'comment': '4ጊዜ አየሁት ሲበዛ ምርጥ ፊልም', 'sentiment': 'positive'}
# {'comment': 'ምርጦች', 'sentiment': 'neutral'}
# {'comment': 'አረየሺዋይመችሺ', 'sentiment': 'neutral'}
# {'comment': 'ጀግናይወለድአቦ', 'sentiment': 'neutral'}
# {'comment': 'አበይመችህየኔጀግና', 'sentiment': 'neutral'}
# {'comment': 'ዋው', 'sentiment': 'neutral'}
# {'comment': 'ዋዉ ሀገሬ ሰላምሽ ይብዛልኝ', 'sentiment': 'neutral'}
# {'comment': 'የጠላ ቤት ጫወታ።', 'sentiment': 'neutral'}
# {'comment': 'ዋዉ ምርጥ ፊልም', 'sentiment': 'positive'}
# {'comment': 'አቤት ሲያምር ፊልምምምምምምም ብሎ ዝም ነው እስኪ ገጠር በመወለዳችሁ የምትኮሩ ልቁጠራችሁያላያችሁ እዩት ምርጥጥጥጥጥጥጥጥ ነው......', 'sentiment': 'neutral'}
# {'comment': 'ዋዉዉዉዉ', 'sentiment': 'neutral'}
# {'comment': 'ክብርና ምስጋና ለደጉ ባላገሩ', 'sentiment': 'positive'}
# {'comment': 'ከቲክቶክ አይቶ የመጣ እንደኔ', 'sentiment': 'neutral'}
# {'comment': 'ለስንተኛ ጊዜ እንዳየሁት በጣም ምርጥ ፊልም! ቆንጆ የታሪክ ፍሰት ያልጠበቁት ካራክተር (ሽፍታውን የተጫወተው )ቆንጆ ሎኬሽን ተፈጥሯዊነቱን የጠበቀ! የታሪክ ፍሰቱ!.... ጎበዞች ቃላቶቹን እንዴት እንዳጠኑት... ጎበዝ ዳይሬክተር .... በነካ እጃችሁ አንዳንድ የዘመኑን ደራስያን ብታጠፉልን ኢትዮጵያዉያን የሌለብንን ማንነት የሚአንፀባርቅ ጭብጥ እያመጡ የሚበክሉንን ብታጠፉልን ብቻ እንደዚ አይነት ፊልሞች ያስፈልጉናል ይደገም!', 'sentiment': 'positive'}
# {'comment': '34፡00', 'sentiment': 'neutral'}
# {'comment': 'አይ አማራ', 'sentiment': 'neutral'}
# {'comment': 'ምርጥ ፊልም', 'sentiment': 'positive'}
# {'comment': 'ይኸው ነው የአማራ ታሪክ።መገዳደል', 'sentiment': 'neutral'}
# {'comment': 'አገሬ ማጀቴ', 'sentiment': 'neutral'}
# {'comment': 'በጣም የሚመስጥ ነው', 'sentiment': 'neutral'}
# {'comment': 'እጅግ በጣም ግሩም የሆነ ኢትዮጵያዊ ፊልም ነው ስለ እውነት ቀጥሉበት', 'sentiment': 'positive'}
# {'comment': 'ዋው አንደኛ የምር', 'sentiment': 'neutral'}
# {'comment': 'ፊልም ብሎ ዝም ነው ጄግና ወንድ ውስጤ ነው ኡፍፍፍፍፍፍፍፍፍፍ', 'sentiment': 'neutral'}
# {'comment': 'ዋዉጀግና', 'sentiment': 'neutral'}
# {'comment': 'ፖ ፖ ምርጥ ፊልም የከተማ የራቆት ፊልም ከማየት የጀግና ፊልም ማየት ይሻላል ደሞ የ ደም አይቀ ርም', 'sentiment': 'positive'}
# {'comment': 'ኢንደኔ በ 2016 የያ', 'sentiment': 'neutral'}
# {'comment': 'ቁንጮ ከሆኑ ፊልሞች መሃከል ያስቀመጥኩት ፊልም ነው! ነገር ግን ከሰማሁት መረጃ አኳያ ዋና ደራሲው ታውቆ &#39;ክሬዲቱን&#39; ብቻ ሳይሆን የላቡንም ዋጋ ቢያገኝ እላለሁ! እናንተስ???', 'sentiment': 'neutral'}
# {'comment': 'ጀግንነት', 'sentiment': 'neutral'}
# {'comment': 'ውይ ያገሮቸስዎች ስላማችሁይብዛ ይጨምርላችሂ', 'sentiment': 'neutral'}
# {'comment': 'ሸጋ ፊልም ነው', 'sentiment': 'neutral'}
# {'comment': 'ሸዋ', 'sentiment': 'neutral'}
# {'comment': 'ይለያል', 'sentiment': 'neutral'}
# {'comment': 'ቆንጆ ፌልም ነው እናመሰግናለን', 'sentiment': 'positive'}
# {'comment': 'ባለትዳር የሆኑ ሰዎች አብረው ነው የሚቆርቡት ፊልም ላይ መንፈሳዊ ነገር ስትሰሩ አባቶችን አማክሩ', 'sentiment': 'neutral'}
# {'comment': 'ዘዬውን ለመቻል ሞኝ መሠላችሁሳ የገጠር ሰው ሲያወራ የሚላዘዝ የሚመስላችሁ ነገርስ', 'sentiment': 'negative'}
# {'comment': 'ትላንትና ማታ በጣትህ ወጋኀኝ ምን አለ ዛሬም በወጋህኝ', 'sentiment': 'neutral'}
# {'comment': 'ዜድነኝ', 'sentiment': 'neutral'}
# {'comment': 'ዋውውውውውውውውውውው ቃላት ያጥረኛል ምብዬ ልግለፅው ዋዉውውው', 'sentiment': 'neutral'}
# {'comment': 'ሚገርም ፊልም እወዳቸዋለሁ', 'sentiment': 'neutral'}
# {'comment': 'ስፍሬ፣ነዉኮ፣የምር፣ሸይሳፍላላቸዉ፣፣ነበር፣አያቁኚም፣አሁን፣ከቱሁሉ', 'sentiment': 'neutral'}
# {'comment': 'እንሳሮ<>ገምዛ<>ሸዋ ላይ እኮ ፊልም አይሰራ በጣም ደስ የሚል ፊልም ከ 100/100 ወ', 'sentiment': 'positive'}
# {'comment': 'ኣንደኛ ነው ፊልም ነው', 'sentiment': 'neutral'}
# {'comment': 'በጣም በጣም ምርጥዬ ፊልም ነው', 'sentiment': 'neutral'}
# {'comment': 'ጥሩ ፊልም ነው', 'sentiment': 'positive'}
# {'comment': 'መጀመሪያ ኮሜንት የማነበው ነገርስ', 'sentiment': 'neutral'}
# {'comment': 'ገምዛ ምርጥ ፊልም', 'sentiment': 'positive'}
# {'comment': 'እኔ ሸዋ ነኝ ግን አሁን ድሬ ዳዋ ነኝ እናቴ አባቴ አያቴ ሀገሬ ናፍቆኛል ፊልሙን ሳየው ደሞ ሆድ ባሰኝ', 'sentiment': 'neutral'}
# {'comment': 'አቤት ደስ የሚል ፊልም', 'sentiment': 'positive'}
# {'comment': 'ይህን ፌልሞ እደኔ ደጋግሞ ያየው አለ', 'sentiment': 'neutral'}
# {'comment': 'ዜድዬ ነሽ ልበል ዋው ጎበዘሻል', 'sentiment': 'neutral'}
# {'comment': 'ዋው በጣም ያምራል', 'sentiment': 'positive'}
# {'comment': 'ዋው ምርጥ ፊልም በርቱ', 'sentiment': 'positive'}
# {'comment': 'በጣም አሪፍ ፋልም በጉጉት ነው የጨረስኩት', 'sentiment': 'positive'}
# {'comment': 'እምየ ገጠር', 'sentiment': 'neutral'}
# {'comment': 'ምርጥ ስራ ነው ማሪምን ጎንደሬ ነኝ ግን ሸዊወችን ሙቸ ነው ምወዳቸው ደስ ሲሉ', 'sentiment': 'positive'}
# {'comment': 'እንደዚህ አይነት አገረኛ ፊልም ብቻ ስሩ', 'sentiment': 'neutral'}
# {'comment': 'ገልቱ በላይይነህ የምትባለው እሴትላይ መሳሪያ ትተኩሳለህ', 'sentiment': 'neutral'}
# {'comment': 'ጀግናሰው ደስ ይለኛል', 'sentiment': 'neutral'}
# {'comment': 'እንሳሮ<>ገዳይ ሲያረፋፍድ<>ግምዛ<><>ግሩም ጥበብ!', 'sentiment': 'neutral'}
# {'comment': 'ይፋት ገምዛ ማጀቴ ነው አፆኪያ እያላችሁ ነገር አትቆስቁሱ እኛ አፆኪያ አይደለንም ይፋቶች ነን', 'sentiment': 'neutral'}
# {'comment': 'ኡመሬ', 'sentiment': 'neutral'}
# {'comment': 'የገሬ ልጅ የሰፈሬ ልጅዘነብ', 'sentiment': 'neutral'}
# {'comment': 'ውይ በጣም ምርጥ ፊልም ነው', 'sentiment': 'positive'}
# {'comment': 'ባህሉሉ ወጉን የጠበቀ ምርጥ ፊልም', 'sentiment': 'positive'}
# {'comment': 'ፊልሙ ያምራ ግን የገጠር አማረኛ በጭራሽ አልቻሉበትም።', 'sentiment': 'neutral'}
# {'comment': 'ዋው አማራ አማራ መሆን አማረኝ', 'sentiment': 'neutral'}
# {'comment': 'ምርጥ ፊልም ያምራል ግን የምታዘበው ነገር የአወራር አክሰንት ግን የጎጃም ከከትማ አወራር በምንም አይለያየ የወሎ ና የሸዋ አክሰንት ይገመኛል', 'sentiment': 'positive'}
# {'comment': 'አገሬ ሽዋ ሰላምሽ ይብዛልኝ', 'sentiment': 'neutral'}
# {'comment': 'በጣም ደስ የሚል ፊልም ነው ግን ሰውነቴ እየተንቀጠቀጠ ጨረስኩት', 'sentiment': 'positive'}
# {'comment': 'ኮቴ ጫማና ቪላ ቤት ማየት ነበር የሠለቼኝ ባራገር እዴዚህ ዴስ ይላልዴ በአላህ ሣልሠለች ያየሁት ፊልም', 'sentiment': 'neutral'}
# {'comment': 'ቆንጆ ።', 'sentiment': 'positive'}
# {'comment': 'አማራነቴ ኩራቴ', 'sentiment': 'neutral'}
# {'comment': 'መላየ አይትዝታ', 'sentiment': 'neutral'}
# {'comment': 'ግንን ሁሉም ገጠር እድህ ነው እደ እሚወጉት ምነው አበላሹብን', 'sentiment': 'neutral'}
# {'comment': 'ዋው ፓ እደዚህ አይነት ፊልም ሥሩ ያባቶቻችንን መሬት ማንም አይነካት', 'sentiment': 'neutral'}
# {'comment': 'ማጀቴ አገሪ ሠላምሺ ይመለስ እባዬ መጣ ስሟን ስሠማ', 'sentiment': 'neutral'}
# {'comment': 'አንፆኪያ ገምዛ ሀገሬ', 'sentiment': 'neutral'}
# {'comment': 'ምርጥ ስራ ከአንሳሮ ቀጥሎ', 'sentiment': 'positive'}
# {'comment': 'እስኪ ሳሎዝ ትዝ ያለው ማነው ወኔ ሰፈሪ አይ እስኪ ሀገር ሰላም ይሁንልን', 'sentiment': 'positive'}
# {'comment': 'ዘዉድ የኔ ጀግና', 'sentiment': 'positive'}
# {'comment': 'እንደዚህ ፊልም ተመስጨ ደጋግሜ ያየሁት ፊልም የለም, ምክንያቱም አሁን ላይ ሙሉ ቤተሰብ እየረሸኑ የሰው ርስት የሚወርሱት ሰዎች እንዳስተውስ ያስገድደኛል, <><>ንፁሃን እየገደሉ የሰው ርስት የሚወርሩ ለነገው ወዮላቸው።', 'sentiment': 'neutral'}
# {'comment': 'ኡመር ቺቺ ለምን ሳይገደል?', 'sentiment': 'neutral'}
# {'comment': 'ቁጥር /2/እንሳሮ', 'sentiment': 'neutral'}
# {'comment': 'ግን እንደዚ አይነት አለ በስማአብ በቀል በቃ እንደ ደሮ ዝም ብሎ መድፋት', 'sentiment': 'neutral'}
# {'comment': 'ፊልሙ ያስተላለፈው መልዕክት ምንድነው ? መሬት (እርስት) ከሰው ህይወትም ይበልጣል ነው? ያን ሁሉ ሰው ጨርሶ ሲያበቃ በቀል የእግዚአብሔር ነው አላለም ሃሃሃሃ...', 'sentiment': 'positive'}
# {'comment': 'አባቴን የማየው እይ9መሰለኝ አፍጥጬ ገበያተኛውን የማየው ነገርስ', 'sentiment': 'neutral'}
# {'comment': 'በዚህ ዘመን የተመታ ነው የ ጥራቱ።', 'sentiment': 'neutral'}
# {'comment': 'ዋው ጥሎብኝ ጀግና እወዳለሁ', 'sentiment': 'positive'}
# {'comment': 'ሀይ', 'sentiment': 'neutral'}
# {'comment': 'በጣምደስይላል', 'sentiment': 'neutral'}
# ...
# {'comment': 'እነዚህን መረሸን ብቻ ነው: ማን እነሱን ይቀልባል እስር ቤት', 'sentiment': 'neutral'}
# {'comment': 'ምድረ ገጠሬ ኬትም ተስብስበህ አዲሳባ ትገባለክ ከዛ የፋራ ስራህን ትሰራለክ እነዚን ደርድረክ ግባር ግባሩን ብሎ ከዚ አለም መሸኝት ነው ፋራ እደሆኑ ንግግራቸው ሁሉም የሰታውቃል', 'sentiment': 'neutral'}
# {'comment': 'እነዚህን የባንዳ ልጆች ለሌላውም ትምህርት የሚሰጥ ከባድ ቅጣት መቀጣት አለባቸው።', 'sentiment': 'neutral'}
# {'comment': 'የባንዳና የዘረኛ መጨረሻው ውርደት ነው', 'sentiment': 'negative'}
# {'comment': 'ጨካኝ እርምጃ ውሰዶ ህዝቡ እስከመቺ በወንበዴ ይሰቃያል ካሚራ ሆሉ ቡታ መግጠማቾ በጣም አሪፍ ነው የሰለጠኖት ሀገራት ወንጀል የሚከላከሉት ካሚራ በየቡታው ሙግጠማቸው ነው', 'sentiment': 'negative'}
# {'comment': 'ሙሉ አዲስ አበባ ላይ ተሰማርተው ያሉት በብዛት ኤርትራውያን ናቸው።', 'sentiment': 'neutral'}
# {'comment': 'ኤርትራውይን ቀይ መስመር እያለፉ ነው', 'sentiment': 'neutral'}
# {'comment': 'ጆሞ መስመር ባጃጅ ላይ ሁለት ሁለት በመሆን ኤርትራውያን ሴቶችም የባለቤቴን ቦርሳዋን በምላጭ ቀደው ሞባይልና ብር ወስደውባታል።', 'sentiment': 'neutral'}
# {'comment': 'ኤርትራውያን ኤርትራውያን ኤርትራውያን ሀገራችን ፈጽሞ አይታ የማታውቀውን ግፍ አያደረጉ ያሉት ሳዋ የስለጠኑ አደገኛ የበቀል አጄንዳ ይዘው የመጡ ኤርትራውያን ናቸው ::', 'sentiment': 'negative'}
# {'comment': 'በቁምጣ ነው የተያዙት ሸለሉ እኮ', 'sentiment': 'neutral'}
# {'comment': 'ለግዜው ብቻ አይሁን ይቀጥል ለአሁኑ እጅግ አስደሳች ነው ።', 'sentiment': 'positive'}
# {'comment': 'እንድንዘረፍ ያረገን መንግሥት ነው ሻዕቢያን አስገብቶ እያኖረ', 'sentiment': 'neutral'}
# {'comment': 'እነዚን አደባባይ ላይ መድፋት ነው ።', 'sentiment': 'neutral'}
# {'comment': 'የ. ፖሊስ ሁላቹም<>የአዳነች አበቤ አስተዳደር ሁላቹም <><>እግዚአብሄር ይባርካቹ።', 'sentiment': 'neutral'}
# {'comment': 'እነዚህ የኤርትራ ስደተኞች ናቸው ፊጋ ኖህ ጀርባ ፊጋ መብራት አሞራው ጤና ጣቢያ ፍየል ቤት አካባቢ ቱሉ ዲምቱ አለም ባንክ በተለይ &;&;ሀረር ሆቴል &;&;አካባቢ በሙሉ ተሰግስገው ነው ያሉት! የኤርትራ ስደተኞችን መንግስት ከሀገራችን ያስወጣልን!', 'sentiment': 'neutral'}
# {'comment': 'የንስር ዐይንና ዱካ ሾው የሰሩትን ጀግንነት በዘገባ መልክ አቅርቡልን!', 'sentiment': 'neutral'}
# {'comment': 'ይረሸኑ', 'sentiment': 'negative'}
# {'comment': 'ሻቢያ', 'sentiment': 'neutral'}
# {'comment': 'እንዴ ሻቢያ', 'sentiment': 'neutral'}
# {'comment': '100 % ሻዕቢያ ናቸው።', 'sentiment': 'neutral'}
# {'comment': 'እጅግ በጣም ጥሩ ሥራ ነዉ በዚሁ ይቀጥል አመሰግናለሁ', 'sentiment': 'positive'}
# {'comment': 'ኤርትራዊያን ናቸው ወይስ የወያኔ ታጣቂ የነበሩ? ሰው እንዲጠነቀቅ ማሳወቅ ነበረባችሁ!!', 'sentiment': 'neutral'}
# {'comment': 'መረጃዎችን ከተለያየ አቅጣጫ ነው የምታቀርቡት ጥሩ ነው በርቱ ቀጥሉበት', 'sentiment': 'positive'}
# {'comment': '.በሱማ አትምጣ', 'sentiment': 'neutral'}
# {'comment': '&;ዘመነ ካሴ ጀጋኑ ጀጋኑ ወዲ አንበሳ &;<> አንቴ ደጊሞ የማኔ ገመድ <>አፍ ኪፍት አፍ : ሠገራ አፋር ቢላ .&;ሎቅማፅ ወደ ሰባዒቲ &;', 'sentiment': 'neutral'}
# {'comment': 'ቢዶ', 'sentiment': 'neutral'}
# {'comment': 'ውሸታም አለቅላቂ', 'sentiment': 'negative'}
# {'comment': 'አህያ ውሸታመ አትረባም', 'sentiment': 'neutral'}
# {'comment': 'ሞቱን ላንተ ለወረኛው ያርግልህ', 'sentiment': 'neutral'}
# {'comment': 'ፓፓፓ ፓም ፓፓም ፓፓም ፓፓፓፓ ፓፓፓ ፓም <>ይህ የጊዜያዊ ወታደራዊ ብልፅግና አዋጅ <>የፈየል ወጠጠጤ ጌረራ <>ልክ አነባበብህ አቶ አሰፋ ይርጉን ቁጭ ¡<>ትምክህት የወጠረው ድንፋታ ዳግማዊ ብልፅግናዊ ደርግ!! <>የታል? ጌረራው ታዲያ???', 'sentiment': 'neutral'}
# {'comment': 'እኩሯ', 'sentiment': 'neutral'}
# {'comment': 'ቅዘናም', 'sentiment': 'neutral'}
# {'comment': 'እረውሽት', 'sentiment': 'neutral'}
# {'comment': 'በምን ማረጋገጫ ነው', 'sentiment': 'neutral'}
# {'comment': 'ሞትን ላተ ያደርገው ሟርተኛ ዜሚ የኛ ጀግና አይሞትም', 'sentiment': 'positive'}
# {'comment': 'አይ ባንዳ፣ ይህቺ ጣቢያ አዲስ ባንዳ ናትደ', 'sentiment': 'neutral'}
# {'comment': 'እውነት ይሆን አሁን ህዝቡ ሁሉ ነቅታል ዘመነ ማን እንደሆነ', 'sentiment': 'positive'}
# {'comment': 'በዚህ ገንዘብ ሠራህ ማለት ነው። ሌባ!', 'sentiment': 'neutral'}
# {'comment': 'ምን አባቱ አይሁድ አማራ ይሙት', 'sentiment': 'neutral'}
# {'comment': 'ቀዳዳ እና ወንፊት ሚዲያ ነህ ተከታይ አይኖርህም', 'sentiment': 'neutral'}
# {'comment': 'ድንገት በቲቪ ሲናገር አይታችሁ ቲቪዉ ላይ ነው መሰል የገደላችሁት ኧ!¡ ነው አይደል?', 'sentiment': 'neutral'}
# {'comment': 'የፈሳም ወሬ', 'sentiment': 'neutral'}
# {'comment': 'የህልም እንጀራ ነዉ በሉት', 'sentiment': 'neutral'}
# {'comment': 'ግድያውን ላንተ ያርገው', 'sentiment': 'neutral'}
# {'comment': 'ዘሜ ክፉዎችን ይጠርጋል። የዘሜ ሀገር ነህ ደግሞ ልንገራችሁ ሞቷል የተባለው ጌታቸው አጠገቡ ማድረጉን አትርሱ ።', 'sentiment': 'neutral'}
# {'comment': 'ዘሜ የአንበሳው ግልገል! የእሳቱ ላንቃ! በሐሜት አይሞትም። ዘመነ ካሴ የአዲሱ አማራ ትውልድ መሪ ነው!! ዘሜ', 'sentiment': 'neutral'}
# {'comment': 'ዉሸት ሞቱን ላንተ ያዲረግልህ', 'sentiment': 'neutral'}
# {'comment': 'የዘመነን ቀንለናንተ ያርገው ምድረ ፔሬዳም ይናፍቃቸዋል ዘመነን መግደል', 'sentiment': 'neutral'}
# {'comment': 'ዘመነ መኖሩ የህዝብን ችግር ሙሁራንን የህክምና ባለሞያዎዥን ተማሪ ውቶ ገብቶ እንዳይኖር እያረጉ የአማራን ህዝብ ችግር አራዘሙት ቡሞት ለሱም ለአማራ ህዝብም ለኢትዮጵያ ግልግል ነው', 'sentiment': 'negative'}
# {'comment': 'ምነ ዩትዮብ እንዳናዳምጥ ባታደርጉን እየዋሻችሁ', 'sentiment': 'neutral'}
# {'comment': 'ደደብ ጋላ ዘሜ ጀግናው አይሞትም', 'sentiment': 'neutral'}
# {'comment': 'ወይ ገንብ እንዲህ ቅዠት ውስጥ ይከታል ሁሌ ውሸት መስማት እንዴት ይሰለቻል', 'sentiment': 'negative'}
# {'comment': 'አንተ መጀመሪያ አማርኛህን አስተካክል ግም ጋላ', 'sentiment': 'neutral'}
# {'comment': 'ኮተት ነህ ዘመነ ካሴ እግዚአብሔር ይጠብቀዋል ሲጀመር ለምን መኪናው ላይ ዘመነ ካሴ ብሎ እንዴት ይፅፋል አታስቀኝ ደደብ', 'sentiment': 'neutral'}
# {'comment': 'ግሞች ሲያምራቹ ይቀራል የሆኦዴድ ገረዶች።', 'sentiment': 'neutral'}
# {'comment': 'ኪኪኪኪኪኪኪ በህልምህ ነው ኪኪኪኪ', 'sentiment': 'neutral'}
# {'comment': 'ሌባው ቀዳዳው ዘራፊው ደፋሪው ማን እንደሆነ እናቃለን አትድከሙ። ማን እንደሞተ ማን እንደተማረከ ህዝቡ ስለሚያቅ አትድከሙ', 'sentiment': 'neutral'}
# {'comment': 'አተራም ጋላ ዘሜ ገና ይገዛሀል ግማታም ጋላ', 'sentiment': 'neutral'}
# {'comment': 'አንተ የመሀይም ልጅ ሰብስክራይብ የአደረጋችሁ የአማራ ልጆች ይሄን ሚዲያ አንሰብስክራይብ በሉት መሀይም።', 'sentiment': 'neutral'}
# {'comment': 'አረህን ግደል', 'sentiment': 'neutral'}
# {'comment': 'ቀዳዳ ሁላ ።አንተን እና አለቃህን ይድፋችሁ', 'sentiment': 'neutral'}
# {'comment': 'ሜሊወን ዘመነ አሉ ዘመነ ምን ግዜም አይሞትም ዘሜ እዲህ አሰቀዘቸው', 'sentiment': 'neutral'}
# {'comment': 'ሀሀሀሀሀሀሀሀሀዘሜ ስራ ይ ነው የዌሸታማ ፔጂ ቆሺሻ እናተ በገደሎችሁቴ ቁጥር የዘሜ እዱሜ ያጨምሪል', 'sentiment': 'neutral'}
# {'comment': 'እኔም ዘርማንዘሬም አርበኛ ዘመነ ካሴ መሆናችንን የማረጋግጥላችሁ በኩራት ነው።<>ዥልጥ ኦሮሞዎች ሆይ እርማችሁን አውጡ።', 'sentiment': 'positive'}
# {'comment': 'ከብት ነህ ግን አንደ ሰው ተወንህ።', 'sentiment': 'neutral'}
# {'comment': 'ፈጣሪ አያደርገውም ዘመነን ሁሉ ኢትዮጵያዊ ይወድደዋል ለምን ታሟርትበታለህ ጀግናስ አይሙት ስንት ፈሪ እያለ', 'sentiment': 'neutral'}
# {'comment': 'የልምክብረት', 'sentiment': 'neutral'}
# {'comment': 'ፈሳም ጋላ የምን አባትክን መጎስት ነው የምታወራ አህያ ጋዘጠኛ ነኝ ባይ አህያ የምትለውን የማታውቅ ደንቆሮ ። አህያው አብይ አህመድ ከሜዲያው ሲጠፋ ምንም አላልክም ? ጌታህ ዘመነ ካሴ ስራ በዝቶበት ሲጠፋክ ግን ሞተ እያልክ በግማታም አፍህ ትለፈልፍ አለህ ። ኧረ እናንተ ዲዳውች አህዮች ምድን ነው ጉዳችሁ??? ድል ድል ድል ለእኛ ወርቆች ለእነ ፋኖ። ሞት ለእኛው ምንሻው እብድ አህያ አብይ አህመድ። ዘርመንዘርክን በየቦታው ወድቆልሀል ሄድና አጥንቱ ልቀም። እውር', 'sentiment': 'positive'}
# {'comment': 'የማንም ገመድ አፍና የአብይ ቱልቱላ ተላላኪ ፍርፋሪ ለቃሚ በንጹሐን ደም የሚነግድ ካድሬ ሲቀደድ ሲተረተር መስማት እንድት ያሳፍራል።አንተም ይህንን ቅደድ ብሎ የላከህ ፋኖ ሲመጣ የት ይሆን መግቢያህደ', 'sentiment': 'neutral'}
# {'comment': 'ምድረ ቀዳዳ !!! የሌለ ቡራ አታውሩ ዘመነን ገደልኩት ካለ 2 አመት ሞላውኩ <>መቀደዱን ተውት!!!', 'sentiment': 'neutral'}
# {'comment': 'አጪበ ርባሪ', 'sentiment': 'neutral'}
# {'comment': 'አብየት ዉሸት ሴት ነህ ግን ዘመነ ካሴ ብሰዋ ጀግና ነዉ እንዳተ ሴታም አይደለም ዉጣ አንተ ልክስክስ ቀንህ ጠብቅ ተበዳለህ', 'sentiment': 'negative'}
# {'comment': 'በመጀመሪያ ራስክን መርምር አንተ ነገ አፈር ነህ ለምን ትዋሻለህ ?', 'sentiment': 'neutral'}
# {'comment': 'እር ይህን አህያ ጋላ ውሽቱን ስሙልኝ ጥላት ባፍ አይሞትም ዘሜ ገና አተን ሳይቀጠቅጥህ ነው አየ አህየው ጠብቅ', 'sentiment': 'neutral'}
# {'comment': 'እር ጉድ ወሽት አተ ቱሪናፋ ዘመነ መቸ ግልብጥ ያርግህ አፈር ብላ ሙተህ እደር እር በስማም ውሽት አያቆይህ', 'sentiment': 'neutral'}
# {'comment': 'አይይይይይይይ ኢትዮጲያዊነት እንድህ ሆነ በቃ ወንድማማቾች እርስበርሳቸዉ መጫረስ?', 'sentiment': 'neutral'}
# {'comment': 'ጠላቱ ይተከል አንተ ተደፋ ደንቆሮ', 'sentiment': 'neutral'}
# {'comment': 'አሩንምአይገድልምአብይዉሸታም', 'sentiment': 'neutral'}
# {'comment': 'ጋላ ለምንድ ነው ጅል የሆነው?', 'sentiment': 'neutral'}
# {'comment': 'ጋላ ግን ሞኝ የሆነው ለምንድን ነው? ኧረ ተማር ደ', 'sentiment': 'negative'}
# {'comment': 'ኧረ መጀመሪያ አማርኛህን አስተካክል ጀዝባ!!!!', 'sentiment': 'neutral'}
# {'comment': 'ልፍጥጥ።', 'sentiment': 'neutral'}
# {'comment': 'ሌላ ምንም አልልህም ቆይ ቆይ ቆይ ቆይ ቆይ ቆይ', 'sentiment': 'neutral'}
# {'comment': 'ቱሪናፋ', 'sentiment': 'neutral'}
# {'comment': 'ላንተ ያድርገዉ ዉሸት የመሆኑ ምልክት የአነጋገርህ ክፋት ማት ያዉርድብህ¡', 'sentiment': 'negative'}
# {'comment': 'ላንተ ያድርገዉ ዉሸት የመሆኑ ምልክት የአነጋገርህ ክፋት ማት ያዉርድብህ¡', 'sentiment': 'negative'}
# {'comment': 'ቀዳዳ', 'sentiment': 'neutral'}
# {'comment': 'ሙሬ አፍ ነህ፣ ውሻ።አንተ ሙትህ እደር።', 'sentiment': 'neutral'}
# {'comment': 'ቀዳዴ ፈሠሥክ', 'sentiment': 'neutral'}
# {'comment': 'ኮ/ል አብይ አህመድ በድንገት ተገደለ።', 'sentiment': 'neutral'}
# {'comment': 'አቤት ውሸት ቀዳዳ', 'sentiment': 'negative'}
# {'comment': 'አታፍርም ስትዋሽ ዛሬ ይህን አልክ ነገስ ምንትል ይሆ ምላስህ ይቆረጥ ማፈሪያነህ አፈርብላ', 'sentiment': 'neutral'}
# {'comment': 'አታፍርም ስትዋሽ ዛሬ ይህን አልክ ነገስ ምንትል ይሆ ምላስህ ይቆረጥ ማፈሪያነህ አፈርብላ', 'sentiment': 'neutral'}
# {'comment': 'ስስእራ', 'sentiment': 'neutral'}
# {'comment': 'ሌባ ብሎክ / ረፖርት አደርግብሃለሁ ተጠንቀቅ', 'sentiment': 'neutral'}
# {'comment': 'ተረተ ተረት አታውሩልን', 'sentiment': 'neutral'}
# {'comment': 'የቃላት እጠቃህም እራሱሲያጸይፍ', 'sentiment': 'neutral'}
# {'comment': 'አህያደንቆሮ ሳምርህይኑር', 'sentiment': 'neutral'}
# {'comment': 'ውሸታም፣ዘመኔ፣አይሞትም', 'sentiment': 'neutral'}
# {'comment': 'አይጋላሉምድነውዘመነንየምፈሩትሽታምጥብጋላ', 'sentiment': 'neutral'}
# {'comment': 'ደደብ። 70 ሚሊዮን አማራ ዘመነዎች ነው', 'sentiment': 'neutral'}
# {'comment': 'አንተድፍትበል', 'sentiment': 'neutral'}
# {'comment': 'ልጓም አፎች! ጅላጅል መከላከያ ! ጋዜጠኛው እና መከላከያዎቹ የኦነግ ሥብስብ ናቸው! ቅሌታሞች !', 'sentiment': 'neutral'}
# {'comment': 'አንተ ግን ምን አይነት ቀዳዳ አደሆንክ ድሮም አውቅሃለሁ ምናልባች አድቀን ሞትህን አደማቀርበው እአግተኛነኝ,,,,,', 'sentiment': 'neutral'}
# {'comment': 'ቀዳዳ ነህ በናትህ', 'sentiment': 'neutral'}
# {'comment': 'ሀሀሀሀሀሀሀሀሀሀሀሀሀ', 'sentiment': 'neutral'}
# {'comment': '4 ኪሎ መጣልህ', 'sentiment': 'neutral'}
# {'comment': 'አቤት ይሄ እንደ ሀገራችን አቡጀዲ ተ ቀ ደ ደ', 'sentiment': 'neutral'}
# {'comment': 'ሲያምራችሁ፡ይቅርርር!!! እጅግ፡አሳፋሪ፡ዜናናናናውሸታም፡የአብይ፡ጡሩንባዎችችችችችችች!!! ዘሜ፡4 ኪሎ፡ገብቶ፡አብይን፡ከነጡሩንባዎቹ፡ያስወግዳልልልልል የዘመነን፡ጦስ፡ውሰዱዱዱ ድልልልልልልልልል ለጀግኖቹ የአማራራራራ ፋኖዎችችችችችችችች የአማራራራራ ፋኖዎችችችችችችችች ይችላሉሉሉሉሉለሉሉሉ ያሽንፋሉሉሉሉሉሉሉ', 'sentiment': 'neutral'}
# {'comment': 'ሁሉም አማራዘመነካሴነው ድልለፋኖ ፍኖኖኖኖኖኖኖዘሜ ዘሜነው ይህንየሚአወሩት ስለሚፈሩትነው', 'sentiment': 'neutral'}
# {'comment': 'ይሔንን ያህል መቀደድ መልካም አይደለም ።<>አድሜጭ የሚጥልህን ውሸት አድርገው', 'sentiment': 'negative'}
# {'comment': 'ጋላ ላንተ ያርግልህ', 'sentiment': 'neutral'}
# {'comment': 'ውሸታም', 'sentiment': 'negative'}
# {'comment': 'አትበላሽ', 'sentiment': 'neutral'}
# {'comment': 'ቀዳዳ ጋላ ንግግርህ ያሥታውቃል ነዳላ!!', 'sentiment': 'neutral'}
# {'comment': 'አንድ ሰው ስንቴ ነው የሚሞመተው?የዘመነ ነብስ ስንት ነው?', 'sentiment': 'neutral'}
# {'comment': 'መንግስት የቀጠረው የወያኔ አማርኛ ፔጅ ነው። አይብልግና እና ህዋት!! ሁሌ የበታችነት እንደተሰማችሁ ይህንን የዋህ ህዝብ አስጨረሳችሁት።', 'sentiment': 'neutral'}
# {'comment': 'እንኮንይሆሆዳምጆንያቀርቶሰንትጀግናይሞትየለይህባንዳገሀነብይግባእሺበጣሞነውየምንጠላው', 'sentiment': 'neutral'}
# {'comment': 'ሲያምርህ ቀረ', 'sentiment': 'neutral'}
# {'comment': 'ይሄ ድረገፅ በሀሰት የተለወሰ ወሬ ያወራል ተከፋይ ይመስለኛል', 'sentiment': 'neutral'}
# {'comment': 'ልዳህህህህህህህህህህ', 'sentiment': 'neutral'}
# {'comment': 'የናፍቅሀል', 'sentiment': 'neutral'}
# {'comment': 'እራሳችሁ ትሞታላችሁ ቅዘናም ስለተንቦጫቦጭክ ታወራለህ ዘመነ ቢሞት ሺ ዘመነ ተወልዷል ጭቃዎች ፈሪ ጅሎች', 'sentiment': 'neutral'}
# {'comment': 'ውሸታሙ መንግሥት እንኳን ዘመነን ፈጣሪንም ገደልኩት ሳይል አይቀርም።', 'sentiment': 'neutral'}
# {'comment': 'ፋኖ ደምባራ ነው', 'sentiment': 'neutral'}
# {'comment': 'ውሸታሞች ቅጥረኛ ብልፅግና ባንዳ ካድሬ ወረኛ ዘመነን ካድሬዎች ገደልነ ካሉ ቆይተዋል ተመስገን ቀብሬዋለሁ ካለ ሰንብቷል ።', 'sentiment': 'neutral'}
# {'comment': 'ድልና ክብር ለኢትዮጵያ መከላካያ ሠራዊት!!!', 'sentiment': 'positive'}
# {'comment': 'ይህ ዘገባ ነው ብለህ የምታቀርበው ለመሆኑ ይህ ስርዓት ተመችቶህ ነው?', 'sentiment': 'neutral'}
# {'comment': 'ግዲያዉን ላተ ያርግልህ', 'sentiment': 'neutral'}
# {'comment': 'የሽፈታችሁ ምልክት እልም እልማችሁ', 'sentiment': 'neutral'}
# {'comment': 'የሸሜ ልጂ', 'sentiment': 'neutral'}
# {'comment': 'እልማችሁ ደስ ይላል', 'sentiment': 'neutral'}
# {'comment': 'አተ ደደብ ቢዲዩ አይባሉም አተጋላ', 'sentiment': 'neutral'}
# {'comment': 'ቀዳዳ', 'sentiment': 'neutral'}
# {'comment': 'ቀዳዳ ሲያምርህ ይቀራል ክርፋታም ምልኮኛ', 'sentiment': 'neutral'}
# {'comment': 'ቱልቱላ አታቅራራ', 'sentiment': 'neutral'}
# {'comment': 'አንተ ጋላ ሳይቀጠቅጥህ መችም አይሞትም', 'sentiment': 'neutral'}
# {'comment': 'ባሪያ ሲጨንቅህ እኮ ነው', 'sentiment': 'neutral'}
# {'comment': 'የግማታም የጋላ ልጅ ዘመነ ሁሉንም የኦሮሞ የጋላን ህዝብ ሳይገል ዘሜ የአማራው ንጉስ አይሞት ሲያምርህ ይቀራል', 'sentiment': 'neutral'}
# {'comment': 'ቢዲወ ምን ማለት ነው<>ተከፋይ ብር አፉ', 'sentiment': 'neutral'}
# {'comment': 'ለሚድነው ፋኖና የኢትዮጵያ መንግሥት የማይደራደሩት ብየ ስጠይቅ ችግሩ አንድ<><>ፋኖ አንድ አደረጃጀት የላቸውም <>ስልጣን ፈልጋይ ብቻ ሆኑና የህዝብን ስቃይ አራዘሙት ወይ በጦርነት አልጨረሱት ወይ በሰላም በንግግር አልጨረሱት ህዝቡ ተሰቃየ', 'sentiment': 'neutral'}
# {'comment': 'አልቀርብህም', 'sentiment': 'neutral'}
# {'comment': 'ማንም ከሞት የሚቀር የለም ነገርግን በሬ ወለደ የምትሉ የአህያ ሹፌሮች ሰው ሁኑ ታሪክ ይቀየራል ድራሽእባክ ጥርግርግ የሚልበት ቀን ይመጣል ምድረ ኩበት ለቃሚ ግዴለም የጊዜ ጉዳይ ነው', 'sentiment': 'neutral'}
# {'comment': 'ሽንታም የሽንታም ልጅ የሆነ ሰው ነው ዘመነ ካሴ ሰላምን አጥብቆ የሚጠላ ሰው ነው ተጠንቅቀ አውቀዋለሁ ወራዳ የንጭቅ ልጅ አንተ ደደብ ጀግና ከሆንክ ጦርነቱን አሸንፍ አማራ ክልልን ተቆጣጠረ ፈሪ ሙትቻ', 'sentiment': 'positive'}
# {'comment': 'ቀዳዳ ጋላ ቦቅቧቃ ውሸታም።የጋላ ተላላኪ ያልቃል ከዚህ አይወጣም', 'sentiment': 'neutral'}
# {'comment': 'ቀዳዳ ዘመነ አይሞትም ውሸት', 'sentiment': 'negative'}
# {'comment': 'ወሬአይከለከል ቀዳባዳ', 'sentiment': 'neutral'}
# {'comment': 'እንደው ምን አለ ለማሳመን እንኳ ፊልሙን ስታቀናብር ብትጠነቀቅ', 'sentiment': 'neutral'}
# {'comment': 'ጅል ጅላጅል ነገር ናችሁ።', 'sentiment': 'neutral'}
# {'comment': 'ቀዳዳ ቱሪናፋ ዘመነ ጋላን ሳያጠፋ ነው የሚሞተው ዘመነ ንጉስ ነው', 'sentiment': 'neutral'}
# {'comment': 'ቱሪናፋ ናችሁ።', 'sentiment': 'neutral'}
# {'comment': 'ሽፍታው የመንግስት ታጣቂ መኪና እየሰበር ነው? ሰው ስለሆነ አንድ ዘመነ ካሴ ሊሞት ይችላል። ግን እመነኝ ዘመነ እስኪ ሞት 100000 ሽ የኦሮሞ ወጣቶች እና ባንዳ አማራዎች ከኢትዮጵያ ይፀዳሉ። ዘመነን ለመግደል ብዙ ሽ የኦሮሞ ወጣቶች ዘምተዋል እየዘመቱም ነው። ግን አልሞተም ነገር ግን ድሃ የኦሮሚያ እናት ልጇን ተነጥቃ ወደ ሞት ይማግዱባታል። እናትም ጥቁር ለብሳ አንብታ ዝም ትላለች። የልጆቻቸውን ሞት ያልሰሙ ደግሞ የኦሮሞ ምድር ይቁጠራቸው የአማራ ምድ ሲኦል ነው። የመጣን ሁሉ ወደ ሞት ስበት ይማግዳል', 'sentiment': 'neutral'}
# {'comment': 'ቱሪናፋ ናችሁ።', 'sentiment': 'neutral'}
# {'comment': 'ጋላ በሕልሙ ቂቤ ባይጣጣ ምን ይብጀው ።', 'sentiment': 'neutral'}
# {'comment': 'አምርህ ይቅር የዘሜ ሞት', 'sentiment': 'neutral'}
# {'comment': 'ቱሪናፋ ጋላ', 'sentiment': 'neutral'}
# {'comment': 'መረጃዎችን ከተለያየ አቅጣጫ ነው የምታቀርቡት ጥሩ ነው በርቱ ቀጥሉበት', 'sentiment': 'positive'}
# {'comment': 'ምን ዓይነቱ ቀዳዳ ነህ', 'sentiment': 'neutral'}
# {'comment': 'ሰላም ለሀገራችን', 'sentiment': 'positive'}
# {'comment': 'እንኳን ደንቆሮው አብይ<>ፈጣሪም ሳያስፈቅድ አይነካው<>አብይን ልብዳው<>አንተ በረዳ አፍ<>ጋዜጠኛ ያንተ መሞት ነው ቀድሞ የታየህ የሰው መስሎህ ነው<>አንተ የበረንዳ አዳሪ ልጅ <><><><>የጅብ አፍ ልጅ', 'sentiment': 'neutral'}
# {'comment': '120 ህዝብ ባለባት አገር 47 ህዝብ ነው የተሳተፈው እሄ ደግሞ የድህነታችን ዋና ማሳያ ነው!!!', 'sentiment': 'neutral'}
# {'comment': 'በ2024 አስረኛ ወር የተገዛ ሼር እስካሁን አልፀና ወይም ተቀባይነት የለው ተብሎ ብር አልተመለሰ። በዛ ላይ ሲገዛ የተከፈለው ተጨማሪ ክፍያ ሁሉ የሚገርም ነው።', 'sentiment': 'neutral'}
# {'comment': 'ቴሌ ዘራፊ ነው ወይስ ለዘራፊዋች ህጋዊ ድጋፍ የሰጣል ........', 'sentiment': 'positive'}
# {'comment': 'ገንዘብ ለመሰብሰብ በጣም ጎበዝ ነሽ ..... ለህዝብ ግን ምንም አልታሰበም እህት ..... ሌብነቱን/ዝርፊያውን በርክቷል ብታስቆሙልን ..... ካርድ ሞልተን መጠቀም አልቻልንም ....', 'sentiment': 'positive'}
# {'comment': 'በርቺ ጀግና ነሽ ።', 'sentiment': 'positive'}
# {'comment': 'ሰለሞን ! በጣም የምትገርም ሰው ነህ ፣ሰላሳ ቢልዮን ብር ለመሸጥ ታስቦ አስር ቢሊዮን ሲሸጥ ግዙፍ ቁጥር ነው ብለህ ልትደልለን ታስባለህ ?', 'sentiment': 'neutral'}
# {'comment': 'ጠ/ሚ አብቹ ሰው አንተን አምኖ ብልፅግናን መረጠ አህያ መንዳት የማችሉትን አስቀምጠህ አፈር አስበላኅው አንተን አምነው ኢትዮ ቴሌኮም ሼር ገዙ ይኅው እቺ አዛባ ቢሰራ ስንት የሚያተርፍ ብር ተንተርሳ ቡክ ያደረጉ ብላ ብዛት ልትናገር በድፍረት አደባባይ ላይ ወጣች በዚህ ደረጃ ህዝብን ምትንቁት ምን አድርጓችሁ ነው!!', 'sentiment': 'neutral'}
# {'comment': 'ፍሬ ህይወት እልም ያልሽ መሀይም ነሽ እኔ ያልገባኝ አንቺ እና አዳነች አብቹን በምንድነው አንቃችሁ ይዛችሁ ስልጣን ላይ ተለጥፋችሁ የቀራችሁትጡረታ ሁሉ ምትወጡ አይመስልም የፖለቲካ ተንታኝ ነኝ ባዩ ስዩም ብሬን ብሎ ኡኡ ብሎ አላስተኛ አለሽ ስዩምን የነካ የለውም በረካአትቅለብለቢ እንድ ነገር አድምተሽ ስሪ እና ወደ ሌላ ሂጂ ሯጭ ሆንሽየብልፅግና አፈሙዝ ዩትዩበሮች ቪዲዮ መቅረፅ የማችል ኢንተርኔት ቤተሰቦቻችንን በቪዲዮ ማግኘት የማንችልበት ኢንተርኔት ይዘች ታሽቃብጫለሽ ዱቄት እሁን ወሬ ትተሽ ሼር ለገዙት ብራቸውን ይዘሽ ለተኛሽበት ወለዱን መክፈል አለብሽ ውይ ለካስ ብልፅግና ጴንጤ ነሽ ላንቺ ህግ የለም ያሻሽን ነው ምታደርጊው', 'sentiment': 'neutral'}
# {'comment': 'ጋዜጠኛ እንደ ድምጽ ማጉያ ነገሮችን አሳምሮ መድገም ሳይሆን ክፍተቶችን አጥንቶ ጠጠር ያሉ ጥያቄዎችን መጠየቅ ይገባዋል። አለበለዛ አዝማሪነት ይሆናል።', 'sentiment': 'neutral'}
# {'comment': 'እረ ተበዘበዝን ምንም ለአገር ቢሆን ጉዳቱ በዛ።', 'sentiment': 'neutral'}
# {'comment': 'የኛ ጀግና በጣᎀ ነውምወደሸ የማከብረሸ', 'sentiment': 'positive'}
# {'comment': 'እናመሰግናለን ሰለሞን እና ፍሬ', 'sentiment': 'neutral'}
# {'comment': 'አቶ ዘመዴነህ የምጣኔ ሃብት ባለሙያ ናቸው እንዴ?', 'sentiment': 'neutral'}
# {'comment': '47377 ዜጎች ሁሉንም ሰርቲ ፋይድ ይሆናሉ ማለት ነው ።', 'sentiment': 'neutral'}
# {'comment': 'ኢትዮቴሌኮም 100 አኽስዮን መሸጥ አልሞ 10 ብቻ መሸጡ ምን ያሳያል።', 'sentiment': 'neutral'}
# {'comment': 'በእናታቹው እኔም የገዛበት ብር ለማስገባት እሰተፊ ላኩልን', 'sentiment': 'neutral'}
# {'comment': 'የቴሌን ስለአክስዮን ሽያጭ ሁለንተናዊ ጉዳትለአገር የገለፅኩስሉሆነ የተፃፈውንማየት ይችላል ዝርዝሩን ከመቶሀያሚሊየን ሕዝብጥቅምእንደሕዝብ በጋራይጠቀማሉ እንደገናደግሞ ለአራባሶስት ሽህደግሞ ከመላው ሕዝብተቆንጥሮ እንደገናልዮተጠቃሚማድረግ እንኳንፍታዊነት ይፍትህሽታ አታውቁትምማለት ነውያደረጋቹህት ልዮየመሐበረሰብ ተጣቃሚነትን ነው የፈጠራቹህት ያውማድረግ በጉልበትሲሆን የሚያስከትለውን ዋጋየሚከፍልይከፍላል። ሌላውየኔትወርክ አገልግሎትሰጭ ኢቲወቴሌኮም ሲሆንፍቃድበመውሰድ ሳፋሪኮምእንዳለይታወቃል ነገርግን ቮዳፎንጨምሮስድስት ደርሷልይህን እምገርምሕዝብም አላወቀምቢብራራ???', 'sentiment': 'neutral'}
# {'comment': 'አቶ ስለሞን ለምን ይህን ያህንል እንደዘገየ አልጠየቅህም። ስድስት ወር ሙሉ ገንዝባችን ሳይሰራ መቆየቲ ተገቢ ነው ወይ?አሁይስ ከመቸ ጀምሮ ነው የአክስዮን ባለቤት የሆንነው??ህዝቡ ማወቅ የሚፈልገው ይሄን ነበር፤', 'sentiment': 'neutral'}
# {'comment': 'ኢትዮጵያ ቴሌኮም ለኢትዮጵያውያን የሸጠው አክሲዮን ይበል የሚባል ነው :: የኢትዮጵያ አየር መንገድም ለዜጎቹ እንደቴሌ ቢከተል ጥሩ ነው እላለሁ በርቱ', 'sentiment': 'positive'}
# {'comment': 'እናመሰግናለን ሰለሞን በርታ', 'sentiment': 'neutral'}
# {'comment': 'ከሚስኪኑ ህዝብ እያዘረፍሽ ይህን ያክል አተረፍኩ እያልሽ መግለጫ ስትሰጪ ሳይሽ በአንቺ የሚተዳደረው ድርጅት የዘረፈው ሚስኪን ህዝብ ነው እሚታየኝ።', 'sentiment': 'neutral'}
# {'comment': 'ወይኔ ፍሬህይወት ታምሩን እንዴት እንደምውዳት', 'sentiment': 'neutral'}
# Labeled data saved to labeled_comments.jsonl

# %% [markdown]
# Chunking the label dataset

# %%
# Function to save labeled data to a JSONL file
def save_labeled_data_to_jsonl(labeled_data, output_file):
    """
    Saves labeled data to a JSONL file.

    Args:
        labeled_data (list): A list of dictionaries containing labeled comments.
        output_file (str): The path to the output JSONL file.
    """
    with open(output_file, "w", encoding="utf-8") as f:
        for data in labeled_data:
            f.write(json.dumps(data, ensure_ascii=False) + "\n")
    print(f"Labeled data saved to {output_file}")

# Main pipeline
if __name__ == "__main__":
    # Path to the folder containing JSONL files
    folder_path = "Amharic_comments"  # Replace with the actual folder path

    # Read comments from the folder
    comments = read_comments_from_folder(folder_path)

    # Load a pre-trained sentiment analysis pipeline
    sentiment_analyzer = pipeline("sentiment-analysis", model="nlptown/bert-base-multilingual-uncased-sentiment")

    # Perform sentiment analysis
    labeled_data = []
    for comment in comments:
        cleaned_comment = clean_comment(comment)
        sentiment = sentiment_analyzer(cleaned_comment)[0]
        labeled_data.append({"comment": comment, "sentiment": sentiment["label"]})

    # Print the labeled data
    for data in labeled_data:
        print(data)

    # Save the labeled data to a JSONL file
    output_file = "labeled_comments.jsonl"  # Replace with your desired output file path
    save_labeled_data_to_jsonl(labeled_data, output_file)
